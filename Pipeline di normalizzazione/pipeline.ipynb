# %% [markdown]
# # Pipeline

# %% [markdown]
# ## PROVE DI TRADUZIONE CON LLM

# %% [markdown]
# definizione modello per la traduzione

# %%
from pipeline_script import crea_modello_traduzione
crea_modello_traduzione()

# %% [markdown]
# test modello per la traduzione

# %%
from pipeline_script import translate_to_english_test

lista_cibi = [
    "pane al mais",  # Corn bread in Italian
    "apple",         # English
    "mela",          # Apple in Italian
    "taco",          # English
    "gâteau",        # Cake in French
    "spaghetti",     # English
    "burrito",       # English
    "alimento",      # Food in Spanish
    "salmon",        # English
    "limone",        # Lemon in Italian
    "cheeseburger",  # English
    "pasta",         # English
    "tortilla",      # English
    "sushi",         # English
    "zucchini",      # English
    "carne",         # Meat in Spanish
    "frutta",        # Fruit in Italian
    "okonomiyaki",   # Japanese savory pancake
    "pomme de terre", # Potato in French
    "\"baguette parisien\"" 
]

for cibo in lista_cibi:
    a = translate_to_english_test(cibo)
# Out:
# pane al mais corn bread
# apple eng
# mela apple
# taco eng
# gâteau cake
# spaghetti eng
# burrito eng
# alimento food
# salmon eng
# limone lemon
# cheeseburger eng
# pasta eng
# tortilla eng
# sushi eng
# zucchini eng
# carne meat
# frutta fruit
# okonomiyaki eng
# pomme de terre potato
# "baguette parisien" eng

# %% [markdown]
# # PIPELINE

# %% [markdown]
# creo normalizzazione degli ingredienti di Foodkg

# %%
from pipeline_script import pipeline

file_input = "../File_CSV/ingredienti_food_kg.csv"
file_output = "../File_CSV/FoodKg_normalizzato_da_pipeline.csv"
pipeline(input_file=file_input, output_file=file_output, mostra_qualcosa=True, mostra_tutto=True)
# Out:
# originale:                               ingredient
# brand rimosso:                           ingredient
# traduzione testo in inglese:             ingredient
# minuscolo:                               ingredient
# sigle espanse:                           ingredient
# rimozione aggettivi:                     ingredient
# rimozione suffissi e prefissi:           ingredient
# rimozione testo parentesi:               ingredient
# rimozione testo dopo virgola:            ingredient
# rimozione punteggiatura:                 ingredient
# rimozione stopwords:                     ingredient
# normalizza quantità:                     ingredient
# rimozione unità di misura:               ingredient
# rimozione valori numerici:               ingredient
# conversione testo al singolare:          ingredient
# normalizza caratteri speciali:           ingredient
# rimozione parole duplicate:              ingredient
# ordinamento alfabetico:                  ingredient
# normalizzazione completa:                ingredient
#
# originale:                               1% fat buttermilk
# brand rimosso:                           1% fat buttermilk
# traduzione testo in inglese:             1% fat buttermilk
# minuscolo:                               1% fat buttermilk
# sigle espanse:                           1% fat buttermilk
# rimozione aggettivi:                     1 % fat buttermilk
# rimozione suffissi e prefissi:           1 % fat buttermilk
# rimozione testo parentesi:               1 % fat buttermilk
# rimozione testo dopo virgola:            1 % fat buttermilk
# rimozione punteggiatura:                 1  fat buttermilk
# rimozione stopwords:                     1 fat buttermilk
# normalizza quantità:                     1 fat buttermilk
# rimozione unità di misura:               1 fat buttermilk
# rimozione valori numerici:               fat buttermilk
# conversione testo al singolare:          fat buttermilk
# normalizza caratteri speciali:           fat buttermilk
# rimozione parole duplicate:              buttermilk fat
# ordinamento alfabetico:                  buttermilk fat
# normalizzazione completa:                buttermilk fat
#
# originale:                               1% fat cottage cheese
# brand rimosso:                           1% fat cottage cheese
# traduzione testo in inglese:             1% fat cottage cheese
# minuscolo:                               1% fat cottage cheese
# sigle espanse:                           1% fat cottage cheese
# rimozione aggettivi:                     1 % fat cottage cheese
# rimozione suffissi e prefissi:           1 % fat cottage cheese
# rimozione testo parentesi:               1 % fat cottage cheese
# rimozione testo dopo virgola:            1 % fat cottage cheese
# rimozione punteggiatura:                 1  fat cottage cheese
# rimozione stopwords:                     1 fat cottage cheese
# normalizza quantità:                     1 fat cottage cheese
# rimozione unità di misura:               1 fat cottage cheese
# rimozione valori numerici:               fat cottage cheese
# conversione testo al singolare:          fat cottage cheese
# normalizza caratteri speciali:           fat cottage cheese
# rimozione parole duplicate:              fat cheese cottage
# ordinamento alfabetico:                  cheese cottage fat
# normalizzazione completa:                cheese cottage fat
#
# originale:                               1% low - fat chocolate milk
# brand rimosso:                           1% low - fat chocolate milk
# traduzione testo in inglese:             1% low - fat chocolate milk
# minuscolo:                               1% low - fat chocolate milk
# sigle espanse:                           1% low - fat chocolate milk
# rimozione aggettivi:                     1 % low - fat chocolate milk
# rimozione suffissi e prefissi:           1 % low - fat chocolate milk
# rimozione testo parentesi:               1 % low - fat chocolate milk
# rimozione testo dopo virgola:            1 % low - fat chocolate milk
# rimozione punteggiatura:                 1  low  fat chocolate milk
# rimozione stopwords:                     1 low fat chocolate milk
# normalizza quantità:                     1 low fat chocolate milk
# rimozione unità di misura:               1 low fat chocolate milk
# rimozione valori numerici:               low fat chocolate milk
# conversione testo al singolare:          low fat chocolate milk
# normalizza caratteri speciali:           low fat chocolate milk
# rimozione parole duplicate:              milk fat chocolate low
# ordinamento alfabetico:                  chocolate fat low milk
# normalizzazione completa:                chocolate fat low milk
#
# originale:                               1% low - fat milk
# brand rimosso:                           1% low - fat milk
# traduzione testo in inglese:             1% low - fat milk
# minuscolo:                               1% low - fat milk
# sigle espanse:                           1% low - fat milk
# rimozione aggettivi:                     1 % low - fat milk
# rimozione suffissi e prefissi:           1 % low - fat milk
# rimozione testo parentesi:               1 % low - fat milk
# rimozione testo dopo virgola:            1 % low - fat milk
# rimozione punteggiatura:                 1  low  fat milk
# rimozione stopwords:                     1 low fat milk
# normalizza quantità:                     1 low fat milk
# rimozione unità di misura:               1 low fat milk
# rimozione valori numerici:               low fat milk
# conversione testo al singolare:          low fat milk
# normalizza caratteri speciali:           low fat milk
# rimozione parole duplicate:              fat milk low
# ordinamento alfabetico:                  fat low milk
# normalizzazione completa:                fat low milk
#
# originale:                               10 - inch corn tortillas
# brand rimosso:                           10 - inch corn tortillas
# traduzione testo in inglese:             10 - inch corn tortillas
# minuscolo:                               10 - inch corn tortillas
# sigle espanse:                           10 - inch corn tortillas
# rimozione aggettivi:                     10 - inch corn tortillas
# rimozione suffissi e prefissi:           10 - inch corn tortillas
# rimozione testo parentesi:               10 - inch corn tortillas
# rimozione testo dopo virgola:            10 - inch corn tortillas
# rimozione punteggiatura:                 10  inch corn tortillas
# rimozione stopwords:                     10 inch corn tortillas
# normalizza quantità:                     10 inch corn tortillas
# rimozione unità di misura:               10 inch corn tortillas
# rimozione valori numerici:               inch corn tortillas
# conversione testo al singolare:          inch corn tortilla
# normalizza caratteri speciali:           inch corn tortilla
# rimozione parole duplicate:              inch tortilla corn
# ordinamento alfabetico:                  corn inch tortilla
# normalizzazione completa:                corn inch tortilla
#
# originale:                               10 - inch flour tortilla
# brand rimosso:                           10 - inch flour tortilla
# traduzione testo in inglese:             10 - inch flour tortilla
# minuscolo:                               10 - inch flour tortilla
# sigle espanse:                           10 - inch flour tortilla
# rimozione aggettivi:                     10 - inch flour tortilla
# rimozione suffissi e prefissi:           10 - inch flour tortilla
# rimozione testo parentesi:               10 - inch flour tortilla
# rimozione testo dopo virgola:            10 - inch flour tortilla
# rimozione punteggiatura:                 10  inch flour tortilla
# rimozione stopwords:                     10 inch flour tortilla
# normalizza quantità:                     10 inch flour tortilla
# rimozione unità di misura:               10 inch flour tortilla
# rimozione valori numerici:               inch flour tortilla
# conversione testo al singolare:          inch flour tortilla
# normalizza caratteri speciali:           inch flour tortilla
# rimozione parole duplicate:              inch tortilla flour
# ordinamento alfabetico:                  flour inch tortilla
# normalizzazione completa:                flour inch tortilla
#
# originale:                               10 - inch flour tortillas
# brand rimosso:                           10 - inch flour tortillas
# traduzione testo in inglese:             10 - inch flour tortillas
# minuscolo:                               10 - inch flour tortillas
# sigle espanse:                           10 - inch flour tortillas
# rimozione aggettivi:                     10 - inch flour tortillas
# rimozione suffissi e prefissi:           10 - inch flour tortillas
# rimozione testo parentesi:               10 - inch flour tortillas
# rimozione testo dopo virgola:            10 - inch flour tortillas
# rimozione punteggiatura:                 10  inch flour tortillas
# rimozione stopwords:                     10 inch flour tortillas
# normalizza quantità:                     10 inch flour tortillas
# rimozione unità di misura:               10 inch flour tortillas
# rimozione valori numerici:               inch flour tortillas
# conversione testo al singolare:          inch flour tortilla
# normalizza caratteri speciali:           inch flour tortilla
# rimozione parole duplicate:              inch tortilla flour
# ordinamento alfabetico:                  flour inch tortilla
# normalizzazione completa:                flour inch tortilla
#
# originale:                               10 - inch pie shell
# brand rimosso:                           10 - inch pie shell
# traduzione testo in inglese:             10 - inch pie shell
# minuscolo:                               10 - inch pie shell
# sigle espanse:                           10 - inch pie shell
# rimozione aggettivi:                     10 - inch pie shell
# rimozione suffissi e prefissi:           10 - inch pie shell
# rimozione testo parentesi:               10 - inch pie shell
# rimozione testo dopo virgola:            10 - inch pie shell
# rimozione punteggiatura:                 10  inch pie shell
# rimozione stopwords:                     10 inch pie shell
# normalizza quantità:                     10 inch pie shell
# rimozione unità di misura:               10 inch pie shell
# rimozione valori numerici:               inch pie shell
# conversione testo al singolare:          inch pie shell
# normalizza caratteri speciali:           inch pie shell
# rimozione parole duplicate:              pie inch shell
# ordinamento alfabetico:                  inch pie shell
# normalizzazione completa:                inch pie shell
#
# originale:                               10 - minute Success rice
# brand rimosso:                           10 - minute success rice
# traduzione testo in inglese:             10 - minute success rice
# minuscolo:                               10 - minute success rice
# sigle espanse:                           10 - minute success rice
# rimozione aggettivi:                     10 - minute success rice
# rimozione suffissi e prefissi:           10 - minute success rice
# rimozione testo parentesi:               10 - minute success rice
# rimozione testo dopo virgola:            10 - minute success rice
# rimozione punteggiatura:                 10  minute success rice
# rimozione stopwords:                     10 minute success rice
# normalizza quantità:                     10 minute success rice
# rimozione unità di misura:               10 minute success rice
# rimozione valori numerici:               minute success rice
# conversione testo al singolare:          minute success rice
# normalizza caratteri speciali:           minute success rice
# rimozione parole duplicate:              success rice minute
# ordinamento alfabetico:                  minute rice success
# normalizzazione completa:                minute rice success
#
# originale:                               10 - minute herb stuffing mix
# brand rimosso:                           10 - minute herb stuffing mix
# traduzione testo in inglese:             10 - minute herb stuffing mix
# minuscolo:                               10 - minute herb stuffing mix
# sigle espanse:                           10 - minute herb stuffing mix
# rimozione aggettivi:                     10 - minute herb stuffing mix
# rimozione suffissi e prefissi:           10 - minute herb stuffing mix
# rimozione testo parentesi:               10 - minute herb stuffing mix
# rimozione testo dopo virgola:            10 - minute herb stuffing mix
# rimozione punteggiatura:                 10  minute herb stuffing mix
# rimozione stopwords:                     10 minute herb stuffing mix
# normalizza quantità:                     10 minute herb stuffing mix
# rimozione unità di misura:               10 minute herb stuffing mix
# rimozione valori numerici:               minute herb stuffing mix
# conversione testo al singolare:          minute herb stuffing mix
# normalizza caratteri speciali:           minute herb stuffing mix
# rimozione parole duplicate:              mix herb minute stuffing
# ordinamento alfabetico:                  herb minute mix stuffing
# normalizzazione completa:                herb minute mix stuffing
#
# originale:                               10% cream
# brand rimosso:                           10% cream
# traduzione testo in inglese:             10% cream
# minuscolo:                               10% cream
# sigle espanse:                           10% cream
# rimozione aggettivi:                     10 % cream
# rimozione suffissi e prefissi:           10 % cream
# rimozione testo parentesi:               10 % cream
# rimozione testo dopo virgola:            10 % cream
# rimozione punteggiatura:                 10  cream
# rimozione stopwords:                     10 cream
# normalizza quantità:                     10 cream
# rimozione unità di misura:               10 cream
# rimozione valori numerici:               cream
# conversione testo al singolare:          cream
# normalizza caratteri speciali:           cream
# rimozione parole duplicate:              cream
# ordinamento alfabetico:                  cream
# normalizzazione completa:                cream
#
# originale:                               100 - Calorie Honey Maid Cinnamon Graham Cracker Crisps
# brand rimosso:                           100 - calorie honey maid cinnamon graham cracker crisps
# traduzione testo in inglese:             100 - calorie honey maid cinnamon graham cracker crisps
# minuscolo:                               100 - calorie honey maid cinnamon graham cracker crisps
# sigle espanse:                           100 - calorie honey maid cinnamon graham cracker crisps
# rimozione aggettivi:                     100 - calorie honey maid cinnamon graham cracker crisps
# rimozione suffissi e prefissi:           100 - calorie honey maid cinnamon graham cracker crisps
# rimozione testo parentesi:               100 - calorie honey maid cinnamon graham cracker crisps
# rimozione testo dopo virgola:            100 - calorie honey maid cinnamon graham cracker crisps
# rimozione punteggiatura:                 100  calorie honey maid cinnamon graham cracker crisps
# rimozione stopwords:                     100 calorie honey maid cinnamon graham cracker crisps
# normalizza quantità:                     100 calorie honey maid cinnamon graham cracker crisps
# rimozione unità di misura:               100 calorie honey maid cinnamon graham cracker crisps
# rimozione valori numerici:               calorie honey maid cinnamon graham cracker crisps
# conversione testo al singolare:          calorie honey maid cinnamon graham cracker crisp
# normalizza caratteri speciali:           calorie honey maid cinnamon graham cracker crisp
# rimozione parole duplicate:              crisp honey graham maid cinnamon calorie cracker
# ordinamento alfabetico:                  calorie cinnamon cracker crisp graham honey maid
# normalizzazione completa:                calorie cinnamon cracker crisp graham honey maid
#
# originale:                               100 - calorie snack pack tapioca pudding
# brand rimosso:                           100 - calorie snack pack tapioca pudding
# traduzione testo in inglese:             100 - calorie snack pack tapioca pudding
# minuscolo:                               100 - calorie snack pack tapioca pudding
# sigle espanse:                           100 - calorie snack pack tapioca pudding
# rimozione aggettivi:                     100 - calorie snack pack tapioca pudding
# rimozione suffissi e prefissi:           100 - calorie snack pack tapioca pudding
# rimozione testo parentesi:               100 - calorie snack pack tapioca pudding
# rimozione testo dopo virgola:            100 - calorie snack pack tapioca pudding
# rimozione punteggiatura:                 100  calorie snack pack tapioca pudding
# rimozione stopwords:                     100 calorie snack pack tapioca pudding
# normalizza quantità:                     100 calorie snack pack tapioca pudding
# rimozione unità di misura:               100 calorie snack pack tapioca pudding
# rimozione valori numerici:               calorie snack pack tapioca pudding
# conversione testo al singolare:          calorie snack pack tapioca pudding
# normalizza caratteri speciali:           calorie snack pack tapioca pudding
# rimozione parole duplicate:              tapioca snack calorie pudding pack
# ordinamento alfabetico:                  calorie pack pudding snack tapioca
# normalizzazione completa:                calorie pack pudding snack tapioca
#
# originale:                               100 proof vodka
# brand rimosso:                           100 proof vodka
# traduzione testo in inglese:             100 proof vodka
# minuscolo:                               100 proof vodka
# sigle espanse:                           100 proof vodka
# rimozione aggettivi:                     100 proof vodka
# rimozione suffissi e prefissi:           100 proof vodka
# rimozione testo parentesi:               100 proof vodka
# rimozione testo dopo virgola:            100 proof vodka
# rimozione punteggiatura:                 100 proof vodka
# rimozione stopwords:                     100 proof vodka
# normalizza quantità:                     100 proof vodka
# rimozione unità di misura:               100 proof vodka
# rimozione valori numerici:               proof vodka
# conversione testo al singolare:          proof vodka
# normalizza caratteri speciali:           proof vodka
# rimozione parole duplicate:              proof vodka
# ordinamento alfabetico:                  proof vodka
# normalizzazione completa:                proof vodka
#
# originale:                               100% bran
# brand rimosso:                           100% bran
# traduzione testo in inglese:             100% bran
# minuscolo:                               100% bran
# sigle espanse:                           100% bran
# rimozione aggettivi:                     100 % bran
# rimozione suffissi e prefissi:           100 % bran
# rimozione testo parentesi:               100 % bran
# rimozione testo dopo virgola:            100 % bran
# rimozione punteggiatura:                 100  bran
# rimozione stopwords:                     100 bran
# normalizza quantità:                     100 bran
# rimozione unità di misura:               100 bran
# rimozione valori numerici:               bran
# conversione testo al singolare:          bran
# normalizza caratteri speciali:           bran
# rimozione parole duplicate:              bran
# ordinamento alfabetico:                  bran
# normalizzazione completa:                bran
#
# originale:                               100% natural raisin date cereal
# brand rimosso:                           100% natural raisin date cereal
# traduzione testo in inglese:             100% natural raisin date cereal
# minuscolo:                               100% natural raisin date cereal
# sigle espanse:                           100% natural raisin date cereal
# rimozione aggettivi:                     100 % natural raisin date cereal
# rimozione suffissi e prefissi:           100 % natural raisin date cereal
# rimozione testo parentesi:               100 % natural raisin date cereal
# rimozione testo dopo virgola:            100 % natural raisin date cereal
# rimozione punteggiatura:                 100  natural raisin date cereal
# rimozione stopwords:                     100 natural raisin date cereal
# normalizza quantità:                     100 natural raisin date cereal
# rimozione unità di misura:               100 natural raisin date cereal
# rimozione valori numerici:               natural raisin date cereal
# conversione testo al singolare:          natural raisin date cereal
# normalizza caratteri speciali:           natural raisin date cereal
# rimozione parole duplicate:              date cereal raisin natural
# ordinamento alfabetico:                  cereal date natural raisin
# normalizzazione completa:                cereal date natural raisin
#
# originale:                               12 - inch flour tortillas
# brand rimosso:                           12 - inch flour tortillas
# traduzione testo in inglese:             12 - inch flour tortillas
# minuscolo:                               12 - inch flour tortillas
# sigle espanse:                           12 - inch flour tortillas
# rimozione aggettivi:                     12 - inch flour tortillas
# rimozione suffissi e prefissi:           12 - inch flour tortillas
# rimozione testo parentesi:               12 - inch flour tortillas
# rimozione testo dopo virgola:            12 - inch flour tortillas
# rimozione punteggiatura:                 12  inch flour tortillas
# rimozione stopwords:                     12 inch flour tortillas
# normalizza quantità:                     12 inch flour tortillas
# rimozione unità di misura:               12 inch flour tortillas
# rimozione valori numerici:               inch flour tortillas
# conversione testo al singolare:          inch flour tortilla
# normalizza caratteri speciali:           inch flour tortilla
# rimozione parole duplicate:              inch tortilla flour
# ordinamento alfabetico:                  flour inch tortilla
# normalizzazione completa:                flour inch tortilla
#
# originale:                               12 - inch pizza crust
# brand rimosso:                           12 - inch pizza crust
# traduzione testo in inglese:             12 - inch pizza crust
# minuscolo:                               12 - inch pizza crust
# sigle espanse:                           12 - inch pizza crust
# rimozione aggettivi:                     12 - inch pizza crust
# rimozione suffissi e prefissi:           12 - inch pizza crust
# rimozione testo parentesi:               12 - inch pizza crust
# rimozione testo dopo virgola:            12 - inch pizza crust
# rimozione punteggiatura:                 12  inch pizza crust
# rimozione stopwords:                     12 inch pizza crust
# normalizza quantità:                     12 inch pizza crust
# rimozione unità di misura:               12 inch pizza crust
# rimozione valori numerici:               inch pizza crust
# conversione testo al singolare:          inch pizza crust
# normalizza caratteri speciali:           inch pizza crust
# rimozione parole duplicate:              inch crust pizza
# ordinamento alfabetico:                  crust inch pizza
# normalizzazione completa:                crust inch pizza
#
# originale:                               15 bean mix
# brand rimosso:                           15 bean mix
# traduzione testo in inglese:             15 bean mix
# minuscolo:                               15 bean mix
# sigle espanse:                           15 bean mix
# rimozione aggettivi:                     15 bean mix
# rimozione suffissi e prefissi:           15 bean mix
# rimozione testo parentesi:               15 bean mix
# rimozione testo dopo virgola:            15 bean mix
# rimozione punteggiatura:                 15 bean mix
# rimozione stopwords:                     15 bean mix
# normalizza quantità:                     15 bean mix
# rimozione unità di misura:               15 bean mix
# rimozione valori numerici:               bean mix
# conversione testo al singolare:          bean mix
# normalizza caratteri speciali:           bean mix
# rimozione parole duplicate:              bean mix
# ordinamento alfabetico:                  bean mix
# normalizzazione completa:                bean mix
#
# originale:                               15 bean soup mix
# brand rimosso:                           15 bean soup mix
# traduzione testo in inglese:             15 bean soup mix
# minuscolo:                               15 bean soup mix
# sigle espanse:                           15 bean soup mix
# rimozione aggettivi:                     15 bean soup mix
# rimozione suffissi e prefissi:           15 bean soup mix
# rimozione testo parentesi:               15 bean soup mix
# rimozione testo dopo virgola:            15 bean soup mix
# rimozione punteggiatura:                 15 bean soup mix
# rimozione stopwords:                     15 bean soup mix
# normalizza quantità:                     15 bean soup mix
# rimozione unità di misura:               15 bean soup mix
# rimozione valori numerici:               bean soup mix
# conversione testo al singolare:          bean soup mix
# normalizza caratteri speciali:           bean soup mix
# rimozione parole duplicate:              soup bean mix
# ordinamento alfabetico:                  bean mix soup
# normalizzazione completa:                bean mix soup
#
# originale:                               15% cream
# brand rimosso:                           15% cream
# traduzione testo in inglese:             15% cream
# minuscolo:                               15% cream
# sigle espanse:                           15% cream
# rimozione aggettivi:                     15 % cream
# rimozione suffissi e prefissi:           15 % cream
# rimozione testo parentesi:               15 % cream
# rimozione testo dopo virgola:            15 % cream
# rimozione punteggiatura:                 15  cream
# rimozione stopwords:                     15 cream
# normalizza quantità:                     15 cream
# rimozione unità di misura:               15 cream
# rimozione valori numerici:               cream
# conversione testo al singolare:          cream
# normalizza caratteri speciali:           cream
# rimozione parole duplicate:              cream
# ordinamento alfabetico:                  cream
# normalizzazione completa:                cream
#
# originale:                               16 bean soup mix
# brand rimosso:                           16 bean soup mix
# traduzione testo in inglese:             16 bean soup mix
# minuscolo:                               16 bean soup mix
# sigle espanse:                           16 bean soup mix
# rimozione aggettivi:                     16 bean soup mix
# rimozione suffissi e prefissi:           16 bean soup mix
# rimozione testo parentesi:               16 bean soup mix
# rimozione testo dopo virgola:            16 bean soup mix
# rimozione punteggiatura:                 16 bean soup mix
# rimozione stopwords:                     16 bean soup mix
# normalizza quantità:                     16 bean soup mix
# rimozione unità di misura:               16 bean soup mix
# rimozione valori numerici:               bean soup mix
# conversione testo al singolare:          bean soup mix
# normalizza caratteri speciali:           bean soup mix
# rimozione parole duplicate:              soup bean mix
# ordinamento alfabetico:                  bean mix soup
# normalizzazione completa:                bean mix soup
#
# originale:                               18% table cream
# brand rimosso:                           18% table cream
# traduzione testo in inglese:             18% table cream
# minuscolo:                               18% table cream
# sigle espanse:                           18% table cream
# rimozione aggettivi:                     18 % table cream
# rimozione suffissi e prefissi:           18 % table cream
# rimozione testo parentesi:               18 % table cream
# rimozione testo dopo virgola:            18 % table cream
# rimozione punteggiatura:                 18  table cream
# rimozione stopwords:                     18 table cream
# normalizza quantità:                     18 table cream
# rimozione unità di misura:               18 table cream
# rimozione valori numerici:               table cream
# conversione testo al singolare:          table cream
# normalizza caratteri speciali:           table cream
# rimozione parole duplicate:              cream table
# ordinamento alfabetico:                  cream table
# normalizzazione completa:                cream table
#
# originale:                               2% buttermilk
# brand rimosso:                           2% buttermilk
# traduzione testo in inglese:             2% buttermilk
# minuscolo:                               2% buttermilk
# sigle espanse:                           2% buttermilk
# rimozione aggettivi:                     2 % buttermilk
# rimozione suffissi e prefissi:           2 % buttermilk
# rimozione testo parentesi:               2 % buttermilk
# rimozione testo dopo virgola:            2 % buttermilk
# rimozione punteggiatura:                 2  buttermilk
# rimozione stopwords:                     2 buttermilk
# normalizza quantità:                     2 buttermilk
# rimozione unità di misura:               2 buttermilk
# rimozione valori numerici:               buttermilk
# conversione testo al singolare:          buttermilk
# normalizza caratteri speciali:           buttermilk
# rimozione parole duplicate:              buttermilk
# ordinamento alfabetico:                  buttermilk
# normalizzazione completa:                buttermilk
#
# originale:                               2% cheddar cheese
# brand rimosso:                           2% cheddar cheese
# traduzione testo in inglese:             2% cheddar cheese
# minuscolo:                               2% cheddar cheese
# sigle espanse:                           2% cheddar cheese
# rimozione aggettivi:                     2 % cheddar cheese
# rimozione suffissi e prefissi:           2 % cheddar cheese
# rimozione testo parentesi:               2 % cheddar cheese
# rimozione testo dopo virgola:            2 % cheddar cheese
# rimozione punteggiatura:                 2  cheddar cheese
# rimozione stopwords:                     2 cheddar cheese
# normalizza quantità:                     2 cheddar cheese
# rimozione unità di misura:               2 cheddar cheese
# rimozione valori numerici:               cheddar cheese
# conversione testo al singolare:          cheddar cheese
# normalizza caratteri speciali:           cheddar cheese
# rimozione parole duplicate:              cheese cheddar
# ordinamento alfabetico:                  cheddar cheese
# normalizzazione completa:                cheddar cheese
#
# originale:                               2% evaporated milk
# brand rimosso:                           2% evaporated milk
# traduzione testo in inglese:             2% evaporated milk
# minuscolo:                               2% evaporated milk
# sigle espanse:                           2% evaporated milk
# rimozione aggettivi:                     2 % evaporated milk
# rimozione suffissi e prefissi:           2 % evaporated milk
# rimozione testo parentesi:               2 % evaporated milk
# rimozione testo dopo virgola:            2 % evaporated milk
# rimozione punteggiatura:                 2  evaporated milk
# rimozione stopwords:                     2 evaporated milk
# normalizza quantità:                     2 evaporated milk
# rimozione unità di misura:               2 evaporated milk
# rimozione valori numerici:               evaporated milk
# conversione testo al singolare:          evaporated milk
# normalizza caratteri speciali:           evaporated milk
# rimozione parole duplicate:              milk evaporated
# ordinamento alfabetico:                  evaporated milk
# normalizzazione completa:                evaporated milk
#
# originale:                               2% fat cottage cheese
# brand rimosso:                           2% fat cottage cheese
# traduzione testo in inglese:             2% fat cottage cheese
# minuscolo:                               2% fat cottage cheese
# sigle espanse:                           2% fat cottage cheese
# rimozione aggettivi:                     2 % fat cottage cheese
# rimozione suffissi e prefissi:           2 % fat cottage cheese
# rimozione testo parentesi:               2 % fat cottage cheese
# rimozione testo dopo virgola:            2 % fat cottage cheese
# rimozione punteggiatura:                 2  fat cottage cheese
# rimozione stopwords:                     2 fat cottage cheese
# normalizza quantità:                     2 fat cottage cheese
# rimozione unità di misura:               2 fat cottage cheese
# rimozione valori numerici:               fat cottage cheese
# conversione testo al singolare:          fat cottage cheese
# normalizza caratteri speciali:           fat cottage cheese
# rimozione parole duplicate:              fat cheese cottage
# ordinamento alfabetico:                  cheese cottage fat
# normalizzazione completa:                cheese cottage fat
#
# originale:                               2% large - curd cottage cheese
# brand rimosso:                           2% large - curd cottage cheese
# traduzione testo in inglese:             2% large - curd cottage cheese
# minuscolo:                               2% large - curd cottage cheese
# sigle espanse:                           2% large - curd cottage cheese
# rimozione aggettivi:                     2 % large - curd cottage cheese
# rimozione suffissi e prefissi:           2 % large - curd cottage cheese
# rimozione testo parentesi:               2 % large - curd cottage cheese
# rimozione testo dopo virgola:            2 % large - curd cottage cheese
# rimozione punteggiatura:                 2  large  curd cottage cheese
# rimozione stopwords:                     2 large curd cottage cheese
# normalizza quantità:                     2 large curd cottage cheese
# rimozione unità di misura:               2 large curd cottage cheese
# rimozione valori numerici:               large curd cottage cheese
# conversione testo al singolare:          large curd cottage cheese
# normalizza caratteri speciali:           large curd cottage cheese
# rimozione parole duplicate:              curd large cheese cottage
# ordinamento alfabetico:                  cheese cottage curd large
# normalizzazione completa:                cheese cottage curd large
#
# originale:                               2% low - fat chocolate milk
# brand rimosso:                           2% low - fat chocolate milk
# traduzione testo in inglese:             2% low - fat chocolate milk
# minuscolo:                               2% low - fat chocolate milk
# sigle espanse:                           2% low - fat chocolate milk
# rimozione aggettivi:                     2 % low - fat chocolate milk
# rimozione suffissi e prefissi:           2 % low - fat chocolate milk
# rimozione testo parentesi:               2 % low - fat chocolate milk
# rimozione testo dopo virgola:            2 % low - fat chocolate milk
# rimozione punteggiatura:                 2  low  fat chocolate milk
# rimozione stopwords:                     2 low fat chocolate milk
# normalizza quantità:                     2 low fat chocolate milk
# rimozione unità di misura:               2 low fat chocolate milk
# rimozione valori numerici:               low fat chocolate milk
# conversione testo al singolare:          low fat chocolate milk
# normalizza caratteri speciali:           low fat chocolate milk
# rimozione parole duplicate:              milk fat chocolate low
# ordinamento alfabetico:                  chocolate fat low milk
# normalizzazione completa:                chocolate fat low milk
#
# originale:                               2% low - fat milk
# brand rimosso:                           2% low - fat milk
# traduzione testo in inglese:             2% low - fat milk
# minuscolo:                               2% low - fat milk
# sigle espanse:                           2% low - fat milk
# rimozione aggettivi:                     2 % low - fat milk
# rimozione suffissi e prefissi:           2 % low - fat milk
# rimozione testo parentesi:               2 % low - fat milk
# rimozione testo dopo virgola:            2 % low - fat milk
# rimozione punteggiatura:                 2  low  fat milk
# rimozione stopwords:                     2 low fat milk
# normalizza quantità:                     2 low fat milk
# rimozione unità di misura:               2 low fat milk
# rimozione valori numerici:               low fat milk
# conversione testo al singolare:          low fat milk
# normalizza caratteri speciali:           low fat milk
# rimozione parole duplicate:              fat milk low
# ordinamento alfabetico:                  fat low milk
# normalizzazione completa:                fat low milk
#
# originale:                               2% mexican cheese blend
# brand rimosso:                           2% mexican cheese blend
# traduzione testo in inglese:             2% mexican cheese blend
# minuscolo:                               2% mexican cheese blend
# sigle espanse:                           2% mexican cheese blend
# rimozione aggettivi:                     2 % mexican cheese blend
# rimozione suffissi e prefissi:           2 % mexican cheese blend
# rimozione testo parentesi:               2 % mexican cheese blend
# rimozione testo dopo virgola:            2 % mexican cheese blend
# rimozione punteggiatura:                 2  mexican cheese blend
# rimozione stopwords:                     2 mexican cheese blend
# normalizza quantità:                     2 mexican cheese blend
# rimozione unità di misura:               2 mexican cheese blend
# rimozione valori numerici:               mexican cheese blend
# conversione testo al singolare:          mexican cheese blend
# normalizza caratteri speciali:           mexican cheese blend
# rimozione parole duplicate:              mexican cheese blend
# ordinamento alfabetico:                  blend cheese mexican
# normalizzazione completa:                blend cheese mexican
#
# originale:                               2% milk
# brand rimosso:                           2% milk
# traduzione testo in inglese:             2% milk
# minuscolo:                               2% milk
# sigle espanse:                           2% milk
# rimozione aggettivi:                     2 % milk
# rimozione suffissi e prefissi:           2 % milk
# rimozione testo parentesi:               2 % milk
# rimozione testo dopo virgola:            2 % milk
# rimozione punteggiatura:                 2  milk
# rimozione stopwords:                     2 milk
# normalizza quantità:                     2 milk
# rimozione unità di misura:               2 milk
# rimozione valori numerici:               milk
# conversione testo al singolare:          milk
# normalizza caratteri speciali:           milk
# rimozione parole duplicate:              milk
# ordinamento alfabetico:                  milk
# normalizzazione completa:                milk
#
# originale:                               2% mozzarella cheese
# brand rimosso:                           2% mozzarella cheese
# traduzione testo in inglese:             2% mozzarella cheese
# minuscolo:                               2% mozzarella cheese
# sigle espanse:                           2% mozzarella cheese
# rimozione aggettivi:                     2 % mozzarella cheese
# rimozione suffissi e prefissi:           2 % mozzarella cheese
# rimozione testo parentesi:               2 % mozzarella cheese
# rimozione testo dopo virgola:            2 % mozzarella cheese
# rimozione punteggiatura:                 2  mozzarella cheese
# rimozione stopwords:                     2 mozzarella cheese
# normalizza quantità:                     2 mozzarella cheese
# rimozione unità di misura:               2 mozzarella cheese
# rimozione valori numerici:               mozzarella cheese
# conversione testo al singolare:          mozzarella cheese
# normalizza caratteri speciali:           mozzarella cheese
# rimozione parole duplicate:              cheese mozzarella
# ordinamento alfabetico:                  cheese mozzarella
# normalizzazione completa:                cheese mozzarella
#
# originale:                               20% sour cream
# brand rimosso:                           20% sour cream
# traduzione testo in inglese:             20% sour cream
# minuscolo:                               20% sour cream
# sigle espanse:                           20% sour cream
# rimozione aggettivi:                     20 % sour cream
# rimozione suffissi e prefissi:           20 % sour cream
# rimozione testo parentesi:               20 % sour cream
# rimozione testo dopo virgola:            20 % sour cream
# rimozione punteggiatura:                 20  sour cream
# rimozione stopwords:                     20 sour cream
# normalizza quantità:                     20 sour cream
# rimozione unità di misura:               20 sour cream
# rimozione valori numerici:               sour cream
# conversione testo al singolare:          sour cream
# normalizza caratteri speciali:           sour cream
# rimozione parole duplicate:              sour cream
# ordinamento alfabetico:                  cream sour
# normalizzazione completa:                cream sour
#
# originale:                               3 - cheese gourmet cheddar blend cheese
# brand rimosso:                           3 - cheese gourmet cheddar blend cheese
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 file_input = "../File_CSV/ingredienti_food_kg.csv"
#       4 file_output = "../File_CSV/FoodKg_normalizzato_da_pipeline.csv"
# ----> 5 pipeline(input_file=file_input, output_file=file_output, mostra_qualcosa=True, mostra_tutto=True)
#
# File c:\Users\gobba\Desktop\Tirocinio_Zedda_Giovanni\Pipeline di normalizzazione\pipeline_script.py:388, in pipeline(input_file, output_file, mostra_tutto, mostra_qualcosa)
#     385     print("brand rimosso:".ljust(40), line)
#     387 # Traduci il testo in inglese
# --> 388 line = translate_to_english(line)
#     389 if mostra_tutto:
#     390     print("traduzione testo in inglese:".ljust(40), line)
#
# File c:\Users\gobba\Desktop\Tirocinio_Zedda_Giovanni\Pipeline di normalizzazione\pipeline_script.py:233, in translate_to_english(text)
#     232 def translate_to_english(text):
# --> 233     response = ollama.generate(model='translation_expert', prompt=text)
#     234     if response['response'].strip() != "eng":
#     235         return response['response']
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\ollama\_client.py:163, in Client.generate(self, model, prompt, suffix, system, template, context, stream, raw, format, images, options, keep_alive)
#     160 if not model:
#     161   raise RequestError('must provide a model')
# --> 163 return self._request_stream(
#     164   'POST',
#     165   '/api/generate',
#     166   json={
#     167     'model': model,
#     168     'prompt': prompt,
#     169     'suffix': suffix,
#     170     'system': system,
#     171     'template': template,
#     172     'context': context or [],
#     173     'stream': stream,
#     174     'raw': raw,
#     175     'images': [_encode_image(image) for image in images or []],
#     176     'format': format,
#     177     'options': options or {},
#     178     'keep_alive': keep_alive,
#     179   },
#     180   stream=stream,
#     181 )
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\ollama\_client.py:99, in Client._request_stream(self, stream, *args, **kwargs)
#      93 def _request_stream(
#      94   self,
#      95   *args,
#      96   stream: bool = False,
#      97   **kwargs,
#      98 ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 99   return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\ollama\_client.py:70, in Client._request(self, method, url, **kwargs)
#      69 def _request(self, method: str, url: str, **kwargs) -> httpx.Response:
# ---> 70   response = self._client.request(method, url, **kwargs)
#      72   try:
#      73     response.raise_for_status()
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# creo normalizzazione delle ricette di hummus

# %%
from pipeline_script import pipeline

input_file = "../File_CSV/hummus_ricette.csv" 
output_file = "../File_CSV/hummus_ricette_normalizzato_da_pipeline.csv" 
pipeline(input_file=input_file, output_file=output_file, mostra_qualcosa=True, mostra_tutto=True)
# Out:
# originale:                               "Cranberry-Orange Caramel Corn"
# brand rimosso:                           "cranberry-orange caramel corn"
# traduzione testo in inglese:             "cranberry-orange caramel corn"
# minuscolo:                               "cranberry-orange caramel corn"
# sigle espanse:                           "cranberry-orange caramel corn"
# rimozione aggettivi:                     `` caramel corn ''
# rimozione suffissi e prefissi:           `` caramel corn ''
# rimozione testo parentesi:               `` caramel corn ''
# rimozione testo dopo virgola:            `` caramel corn ''
# rimozione punteggiatura:                 caramel corn
# rimozione stopwords:                     caramel corn
# normalizza quantità:                     caramel corn
# rimozione unità di misura:               caramel corn
# rimozione valori numerici:               caramel corn
# conversione testo al singolare:          caramel corn
# normalizza caratteri speciali:           caramel corn
# rimozione parole duplicate:              caramel corn
# ordinamento alfabetico:                  caramel corn
# normalizzazione completa:                caramel corn
#
# originale:                               "Cocktail De Camarones"
# brand rimosso:                           "cocktail de camarones"
# traduzione testo in inglese:             shrimp cocktail
# minuscolo:                               shrimp cocktail
# sigle espanse:                           shrimp cocktail
# rimozione aggettivi:                     shrimp cocktail
# rimozione suffissi e prefissi:           shrimp cocktail
# rimozione testo parentesi:               shrimp cocktail
# rimozione testo dopo virgola:            shrimp cocktail
# rimozione punteggiatura:                 shrimp cocktail
# rimozione stopwords:                     shrimp cocktail
# normalizza quantità:                     shrimp cocktail
# rimozione unità di misura:               shrimp cocktail
# rimozione valori numerici:               shrimp cocktail
# conversione testo al singolare:          shrimp cocktail
# normalizza caratteri speciali:           shrimp cocktail
# rimozione parole duplicate:              cocktail shrimp
# ordinamento alfabetico:                  cocktail shrimp
# normalizzazione completa:                cocktail shrimp
#
# originale:                               "Inbal Jerusalem Hotel Snowball"
# brand rimosso:                           "inbal jerusalem hotel snowball"
# traduzione testo in inglese:             "inbal jerusalem hotel snowball"
# minuscolo:                               "inbal jerusalem hotel snowball"
# sigle espanse:                           "inbal jerusalem hotel snowball"
# rimozione aggettivi:                     `` jerusalem hotel snowball ''
# rimozione suffissi e prefissi:           `` jerusalem hotel snowball ''
# rimozione testo parentesi:               `` jerusalem hotel snowball ''
# rimozione testo dopo virgola:            `` jerusalem hotel snowball ''
# rimozione punteggiatura:                 jerusalem hotel snowball
# rimozione stopwords:                     jerusalem hotel snowball
# normalizza quantità:                     jerusalem hotel snowball
# rimozione unità di misura:               jerusalem hotel snowball
# rimozione valori numerici:               jerusalem hotel snowball
# conversione testo al singolare:          jerusalem hotel snowball
# normalizza caratteri speciali:           jerusalem hotel snowball
# rimozione parole duplicate:              snowball hotel jerusalem
# ordinamento alfabetico:                  hotel jerusalem snowball
# normalizzazione completa:                hotel jerusalem snowball
#
# originale:                               "Santorini Roasted Leg of Lamb"
# brand rimosso:                           "santorini roasted leg of lamb"
# traduzione testo in inglese:             "santorini roasted leg of lamb"
# minuscolo:                               "santorini roasted leg of lamb"
# sigle espanse:                           "santorini roasted leg of lamb"
# rimozione aggettivi:                     `` santorini roasted leg of lamb ''
# rimozione suffissi e prefissi:           `` santorini roasted leg of lamb ''
# rimozione testo parentesi:               `` santorini roasted leg of lamb ''
# rimozione testo dopo virgola:            `` santorini roasted leg of lamb ''
# rimozione punteggiatura:                 santorini roasted leg of lamb
# rimozione stopwords:                     santorini roasted leg lamb
# normalizza quantità:                     santorini roasted leg lamb
# rimozione unità di misura:               santorini roasted leg lamb
# rimozione valori numerici:               santorini roasted leg lamb
# conversione testo al singolare:          santorini roasted leg lamb
# normalizza caratteri speciali:           santorini roasted leg lamb
# rimozione parole duplicate:              santorini leg roasted lamb
# ordinamento alfabetico:                  lamb leg roasted santorini
# normalizzazione completa:                lamb leg roasted santorini
#
# originale:                               "Cantonese Chicken Burgers"
# brand rimosso:                           "cantonese chicken burgers"
# traduzione testo in inglese:             "cantonese chicken burgers"
# minuscolo:                               "cantonese chicken burgers"
# sigle espanse:                           "cantonese chicken burgers"
# rimozione aggettivi:                     `` cantonese chicken burgers ''
# rimozione suffissi e prefissi:           `` cantonese chicken burgers ''
# rimozione testo parentesi:               `` cantonese chicken burgers ''
# rimozione testo dopo virgola:            `` cantonese chicken burgers ''
# rimozione punteggiatura:                 cantonese chicken burgers
# rimozione stopwords:                     cantonese chicken burgers
# normalizza quantità:                     cantonese chicken burgers
# rimozione unità di misura:               cantonese chicken burgers
# rimozione valori numerici:               cantonese chicken burgers
# conversione testo al singolare:          cantonese chicken burger
# normalizza caratteri speciali:           cantonese chicken burger
# rimozione parole duplicate:              cantonese chicken burger
# ordinamento alfabetico:                  burger cantonese chicken
# normalizzazione completa:                burger cantonese chicken
#
# originale:                               "Crab Salad With Asparagus, Avocado, and Lime Vinaigrette"
# brand rimosso:                           "crab salad with asparagus, avocado, and lime vinaigrette"
# traduzione testo in inglese:             "crab salad with asparagus, avocado, and lime vinaigrette"
# minuscolo:                               "crab salad with asparagus, avocado, and lime vinaigrette"
# sigle espanse:                           "crab salad with asparagus, avocado, and lime vinaigrette"
# rimozione aggettivi:                     `` crab salad with asparagus , avocado , and lime vinaigrette ''
# rimozione suffissi e prefissi:           `` crab salad with asparagus , avocado , and lime vinaigrette ''
# rimozione testo parentesi:               `` crab salad with asparagus , avocado , and lime vinaigrette ''
# rimozione testo dopo virgola:            `` crab salad with asparagus
# rimozione punteggiatura:                 crab salad with asparagus
# rimozione stopwords:                     crab salad asparagus
# normalizza quantità:                     crab salad asparagus
# rimozione unità di misura:               crab salad asparagus
# rimozione valori numerici:               crab salad asparagus
# conversione testo al singolare:          crab salad asparagus
# normalizza caratteri speciali:           crab salad asparagus
# rimozione parole duplicate:              asparagus crab salad
# ordinamento alfabetico:                  asparagus crab salad
# normalizzazione completa:                asparagus crab salad
#
# originale:                               "Greek Fasolatha (Navy Bean Soup)"
# brand rimosso:                           "greek fasolatha (navy bean soup)"
# traduzione testo in inglese:             "greek fasolatha (navy bean soup)"
# minuscolo:                               "greek fasolatha (navy bean soup)"
# sigle espanse:                           "greek fasolatha (navy bean soup)"
# rimozione aggettivi:                     `` greek fasolatha ( navy bean soup ) ''
# rimozione suffissi e prefissi:           `` greek fasolatha ( navy bean soup ) ''
# rimozione testo parentesi:               `` greek fasolatha  ''
# rimozione testo dopo virgola:            `` greek fasolatha  ''
# rimozione punteggiatura:                 greek fasolatha
# rimozione stopwords:                     greek fasolatha
# normalizza quantità:                     greek fasolatha
# rimozione unità di misura:               greek fasolatha
# rimozione valori numerici:               greek fasolatha
# conversione testo al singolare:          greek fasolatha
# normalizza caratteri speciali:           greek fasolatha
# rimozione parole duplicate:              greek fasolatha
# ordinamento alfabetico:                  fasolatha greek
# normalizzazione completa:                fasolatha greek
#
# originale:                               "Indian Spiced Popcorn"
# brand rimosso:                           "indian spiced popcorn"
# traduzione testo in inglese:             "indian spiced popcorn"
# minuscolo:                               "indian spiced popcorn"
# sigle espanse:                           "indian spiced popcorn"
# rimozione aggettivi:                     `` indian spiced popcorn ''
# rimozione suffissi e prefissi:           `` indian spiced popcorn ''
# rimozione testo parentesi:               `` indian spiced popcorn ''
# rimozione testo dopo virgola:            `` indian spiced popcorn ''
# rimozione punteggiatura:                 indian spiced popcorn
# rimozione stopwords:                     indian spiced popcorn
# normalizza quantità:                     indian spiced popcorn
# rimozione unità di misura:               indian spiced popcorn
# rimozione valori numerici:               indian spiced popcorn
# conversione testo al singolare:          indian spiced popcorn
# normalizza caratteri speciali:           indian spiced popcorn
# rimozione parole duplicate:              popcorn indian spiced
# ordinamento alfabetico:                  indian popcorn spiced
# normalizzazione completa:                indian popcorn spiced
#
# originale:                               "Cajun Chicken Salad"
# brand rimosso:                           "cajun chicken salad"
# traduzione testo in inglese:             "cajun chicken salad"
# minuscolo:                               "cajun chicken salad"
# sigle espanse:                           "cajun chicken salad"
# rimozione aggettivi:                     `` cajun chicken salad ''
# rimozione suffissi e prefissi:           `` cajun chicken salad ''
# rimozione testo parentesi:               `` cajun chicken salad ''
# rimozione testo dopo virgola:            `` cajun chicken salad ''
# rimozione punteggiatura:                 cajun chicken salad
# rimozione stopwords:                     cajun chicken salad
# normalizza quantità:                     cajun chicken salad
# rimozione unità di misura:               cajun chicken salad
# rimozione valori numerici:               cajun chicken salad
# conversione testo al singolare:          cajun chicken salad
# normalizza caratteri speciali:           cajun chicken salad
# rimozione parole duplicate:              cajun chicken salad
# ordinamento alfabetico:                  cajun chicken salad
# normalizzazione completa:                cajun chicken salad
#
# originale:                               "No Knead French Bread"
# brand rimosso:                           "no knead french bread"
# traduzione testo in inglese:             "no knead french bread"
# minuscolo:                               "no knead french bread"
# sigle espanse:                           "no knead french bread"
# rimozione aggettivi:                     `` no french bread ''
# rimozione suffissi e prefissi:           `` no french bread ''
# rimozione testo parentesi:               `` no french bread ''
# rimozione testo dopo virgola:            `` no french bread ''
# rimozione punteggiatura:                 no french bread
# rimozione stopwords:                     french bread
# normalizza quantità:                     french bread
# rimozione unità di misura:               french bread
# rimozione valori numerici:               french bread
# conversione testo al singolare:          french bread
# normalizza caratteri speciali:           french bread
# rimozione parole duplicate:              french bread
# ordinamento alfabetico:                  bread french
# normalizzazione completa:                bread french
#
# originale:                               "Red Onion Focaccia"
# brand rimosso:                           "red onion focaccia"
# traduzione testo in inglese:             "red onion focaccia"
# minuscolo:                               "red onion focaccia"
# sigle espanse:                           "red onion focaccia"
# rimozione aggettivi:                     `` red onion focaccia ''
# rimozione suffissi e prefissi:           `` red onion focaccia ''
# rimozione testo parentesi:               `` red onion focaccia ''
# rimozione testo dopo virgola:            `` red onion focaccia ''
# rimozione punteggiatura:                 red onion focaccia
# rimozione stopwords:                     red onion focaccia
# normalizza quantità:                     red onion focaccia
# rimozione unità di misura:               red onion focaccia
# rimozione valori numerici:               red onion focaccia
# conversione testo al singolare:          red onion focaccia
# normalizza caratteri speciali:           red onion focaccia
# rimozione parole duplicate:              onion red focaccia
# ordinamento alfabetico:                  focaccia onion red
# normalizzazione completa:                focaccia onion red
#
# originale:                               "Sausage and Spinach Penne Casserole"
# brand rimosso:                           "sausage and spinach penne casserole"
# traduzione testo in inglese:             "sausage and spinach penne casserole"
# minuscolo:                               "sausage and spinach penne casserole"
# sigle espanse:                           "sausage and spinach penne casserole"
# rimozione aggettivi:                     `` sausage and spinach penne casserole ''
# rimozione suffissi e prefissi:           `` sausage and spinach penne casserole ''
# rimozione testo parentesi:               `` sausage and spinach penne casserole ''
# rimozione testo dopo virgola:            `` sausage and spinach penne casserole ''
# rimozione punteggiatura:                 sausage and spinach penne casserole
# rimozione stopwords:                     sausage spinach penne casserole
# normalizza quantità:                     sausage spinach penne casserole
# rimozione unità di misura:               sausage spinach penne casserole
# rimozione valori numerici:               sausage spinach penne casserole
# conversione testo al singolare:          sausage spinach penne casserole
# normalizza caratteri speciali:           sausage spinach penne casserole
# rimozione parole duplicate:              penne casserole spinach sausage
# ordinamento alfabetico:                  casserole penne sausage spinach
# normalizzazione completa:                casserole penne sausage spinach
#
# originale:                               "Minnesota Wild Rice Salad"
# brand rimosso:                           "minnesota wild rice salad"
# traduzione testo in inglese:             "minnesota wild rice salad"
# minuscolo:                               "minnesota wild rice salad"
# sigle espanse:                           "minnesota wild rice salad"
# rimozione aggettivi:                     `` minnesota wild rice salad ''
# rimozione suffissi e prefissi:           `` minnesota wild rice salad ''
# rimozione testo parentesi:               `` minnesota wild rice salad ''
# rimozione testo dopo virgola:            `` minnesota wild rice salad ''
# rimozione punteggiatura:                 minnesota wild rice salad
# rimozione stopwords:                     minnesota wild rice salad
# normalizza quantità:                     minnesota wild rice salad
# rimozione unità di misura:               minnesota wild rice salad
# rimozione valori numerici:               minnesota wild rice salad
# conversione testo al singolare:          minnesota wild rice salad
# normalizza caratteri speciali:           minnesota wild rice salad
# rimozione parole duplicate:              wild minnesota rice salad
# ordinamento alfabetico:                  minnesota rice salad wild
# normalizzazione completa:                minnesota rice salad wild
#
# originale:                               "Avocado Salsa Recipe"
# brand rimosso:                           "avocado salsa recipe"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 input_file = "../File_CSV/hummus_ricette.csv"
#       4 output_file = "../File_CSV/hummus_ricette_normalizzato_da_pipeline.csv"
# ----> 6 pipeline(input_file=input_file, output_file=output_file, mostra_qualcosa=True, mostra_tutto=True)
#
# File c:\Users\gobba\Desktop\Tirocinio_Zedda_Giovanni\Pipeline di normalizzazione\pipeline_script.py:388, in pipeline(input_file, output_file, mostra_tutto, mostra_qualcosa)
#     385     print("brand rimosso:".ljust(40), line)
#     387 # Traduci il testo in inglese
# --> 388 line = translate_to_english(line)
#     389 if mostra_tutto:
#     390     print("traduzione testo in inglese:".ljust(40), line)
#
# File c:\Users\gobba\Desktop\Tirocinio_Zedda_Giovanni\Pipeline di normalizzazione\pipeline_script.py:233, in translate_to_english(text)
#     232 def translate_to_english(text):
# --> 233     response = ollama.generate(model='translation_expert', prompt=text)
#     234     if response['response'].strip() != "eng":
#     235         return response['response']
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\ollama\_client.py:163, in Client.generate(self, model, prompt, suffix, system, template, context, stream, raw, format, images, options, keep_alive)
#     160 if not model:
#     161   raise RequestError('must provide a model')
# --> 163 return self._request_stream(
#     164   'POST',
#     165   '/api/generate',
#     166   json={
#     167     'model': model,
#     168     'prompt': prompt,
#     169     'suffix': suffix,
#     170     'system': system,
#     171     'template': template,
#     172     'context': context or [],
#     173     'stream': stream,
#     174     'raw': raw,
#     175     'images': [_encode_image(image) for image in images or []],
#     176     'format': format,
#     177     'options': options or {},
#     178     'keep_alive': keep_alive,
#     179   },
#     180   stream=stream,
#     181 )
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\ollama\_client.py:99, in Client._request_stream(self, stream, *args, **kwargs)
#      93 def _request_stream(
#      94   self,
#      95   *args,
#      96   stream: bool = False,
#      97   **kwargs,
#      98 ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 99   return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\ollama\_client.py:70, in Client._request(self, method, url, **kwargs)
#      69 def _request(self, method: str, url: str, **kwargs) -> httpx.Response:
# ---> 70   response = self._client.request(method, url, **kwargs)
#      72   try:
#      73     response.raise_for_status()
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\gobba\miniconda3\envs\kambinete\lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# creo normalizzazione degli ingredienti di off

# %%
from pipeline_script import pipeline

input_file = "../File_CSV/off_ricette.csv"  
output_file = "../File_CSV/off_ricette_normalizzato_da_pipeline.csv"  
pipeline(input_file=input_file, output_file=output_file, mostra_qualcosa=True, mostra_tutto=True)
# Out:
# originale:                               "Tonno Rio Mare"
# brand rimosso:                           "tonno rio mare"
# traduzione testo in inglese:             tuna from the sea
# minuscolo:                               tuna from the sea
# sigle espanse:                           tuna from the sea
# rimozione aggettivi:                     tuna from the sea
# rimozione suffissi e prefissi:           tuna from the sea
# rimozione testo parentesi:               tuna from the sea
# rimozione testo dopo virgola:            tuna from the sea
# rimozione punteggiatura:                 tuna from the sea
# rimozione stopwords:                     tuna sea
# normalizza quantità:                     tuna sea
# rimozione unità di misura:               tuna sea
# rimozione valori numerici:               tuna sea
# conversione testo al singolare:          tuna sea
# normalizza caratteri speciali:           tuna sea
# rimozione parole duplicate:              tuna sea
# ordinamento alfabetico:                  sea tuna
# normalizzazione completa:                sea tuna
#
# originale:                               " moutarde au moût de raisin "
# brand rimosso:                           " moutarde au moût de raisin "
# traduzione testo in inglese:             grape must mustard
# minuscolo:                               grape must mustard
# sigle espanse:                           grape must mustard
# rimozione aggettivi:                     grape must
# rimozione suffissi e prefissi:           grape must
# rimozione testo parentesi:               grape must
# rimozione testo dopo virgola:            grape must
# rimozione punteggiatura:                 grape must
# rimozione stopwords:                     grape must
# normalizza quantità:                     grape must
# rimozione unità di misura:               grape must
# rimozione valori numerici:               grape must
# conversione testo al singolare:          grape must
# normalizza caratteri speciali:           grape must
# rimozione parole duplicate:              must grape
# ordinamento alfabetico:                  grape must
# normalizzazione completa:                grape must
#
# originale:                               "Sauce Sweety chili 0%"
# brand rimosso:                           "sauce sweety chili 0%"
# traduzione testo in inglese:             "sauce sweety chili 0%"
# minuscolo:                               "sauce sweety chili 0%"
# sigle espanse:                           "sauce sweety chili 0%"
# rimozione aggettivi:                     `` sauce sweety chili 0 % ''
# rimozione suffissi e prefissi:           `` sauce sweety chili 0 % ''
# rimozione testo parentesi:               `` sauce sweety chili 0 % ''
# rimozione testo dopo virgola:            `` sauce sweety chili 0 % ''
# rimozione punteggiatura:                 sauce sweety chili 0
# rimozione stopwords:                     sauce sweety chili 0
# normalizza quantità:                     sauce sweety chili 0
# rimozione unità di misura:               sauce sweety chili 0
# rimozione valori numerici:               sauce sweety chili
# conversione testo al singolare:          sauce sweety chili
# normalizza caratteri speciali:           sauce sweety chili
# rimozione parole duplicate:              sauce chili sweety
# ordinamento alfabetico:                  chili sauce sweety
# normalizzazione completa:                chili sauce sweety
#
# originale:                               "Pistou d'ail des ours"
# brand rimosso:                           "pistou d'ail des ours"
# traduzione testo in inglese:             bear garlic pesto
# minuscolo:                               bear garlic pesto
# sigle espanse:                           bear garlic pesto
# rimozione aggettivi:                     bear garlic pesto
# rimozione suffissi e prefissi:           bear garlic pesto
# rimozione testo parentesi:               bear garlic pesto
# rimozione testo dopo virgola:            bear garlic pesto
# rimozione punteggiatura:                 bear garlic pesto
# rimozione stopwords:                     bear garlic pesto
# normalizza quantità:                     bear garlic pesto
# rimozione unità di misura:               bear garlic pesto
# rimozione valori numerici:               bear garlic pesto
# conversione testo al singolare:          bear garlic pesto
# normalizza caratteri speciali:           bear garlic pesto
# rimozione parole duplicate:              garlic bear pesto
# ordinamento alfabetico:                  bear garlic pesto
# normalizzazione completa:                bear garlic pesto
#
# originale:                               "Pain maïs"
# brand rimosso:                           "pain maïs"
# traduzione testo in inglese:             corn bread
# minuscolo:                               corn bread
# sigle espanse:                           corn bread
# rimozione aggettivi:                     corn bread
# rimozione suffissi e prefissi:           corn bread
# rimozione testo parentesi:               corn bread
# rimozione testo dopo virgola:            corn bread
# rimozione punteggiatura:                 corn bread
# rimozione stopwords:                     corn bread
# normalizza quantità:                     corn bread
# rimozione unità di misura:               corn bread
# rimozione valori numerici:               corn bread
# conversione testo al singolare:          corn bread
# normalizza caratteri speciali:           corn bread
# rimozione parole duplicate:              bread corn
# ordinamento alfabetico:                  bread corn
# normalizzazione completa:                bread corn
#
# originale:                               "Salade de carottes râpées"
# brand rimosso:                           "salade de carottes râpées"
# traduzione testo in inglese:             shredded carrot salad
# minuscolo:                               shredded carrot salad
# sigle espanse:                           shredded carrot salad
# rimozione aggettivi:                     shredded carrot salad
# rimozione suffissi e prefissi:           shredded carrot salad
# rimozione testo parentesi:               shredded carrot salad
# rimozione testo dopo virgola:            shredded carrot salad
# rimozione punteggiatura:                 shredded carrot salad
# rimozione stopwords:                     shredded carrot salad
# normalizza quantità:                     shredded carrot salad
# rimozione unità di misura:               shredded carrot salad
# rimozione valori numerici:               shredded carrot salad
# conversione testo al singolare:          shredded carrot salad
# normalizza caratteri speciali:           shredded carrot salad
# rimozione parole duplicate:              carrot salad shredded
# ordinamento alfabetico:                  carrot salad shredded
# normalizzazione completa:                carrot salad shredded
#
# originale:                               "Fromage blanc aux myrtilles"
# brand rimosso:                           "fromage blanc aux myrtilles"
# traduzione testo in inglese:             white cheese with blueberries
# minuscolo:                               white cheese with blueberries
# sigle espanse:                           white cheese with blueberries
# rimozione aggettivi:                     white cheese with blueberries
# rimozione suffissi e prefissi:           white cheese with blueberries
# rimozione testo parentesi:               white cheese with blueberries
# rimozione testo dopo virgola:            white cheese with blueberries
# rimozione punteggiatura:                 white cheese with blueberries
# rimozione stopwords:                     white cheese blueberries
# normalizza quantità:                     white cheese blueberries
# rimozione unità di misura:               white cheese blueberries
# rimozione valori numerici:               white cheese blueberries
# conversione testo al singolare:          white cheese blueberry
# normalizza caratteri speciali:           white cheese blueberry
# rimozione parole duplicate:              cheese blueberry white
# ordinamento alfabetico:                  blueberry cheese white
# normalizzazione completa:                blueberry cheese white
#
# originale:                               "Baguette parisien"
# brand rimosso:                           "baguette parisien"
# traduzione testo in inglese:             "baguette parisien"
# minuscolo:                               "baguette parisien"
# sigle espanse:                           "baguette parisien"
# rimozione aggettivi:                     `` baguette parisien ''
# rimozione suffissi e prefissi:           `` baguette parisien ''
# rimozione testo parentesi:               `` baguette parisien ''
# rimozione testo dopo virgola:            `` baguette parisien ''
# rimozione punteggiatura:                 baguette parisien
# rimozione stopwords:                     baguette parisien
# normalizza quantità:                     baguette parisien
# rimozione unità di misura:               baguette parisien
# rimozione valori numerici:               baguette parisien
# conversione testo al singolare:          baguette parisien
# normalizza caratteri speciali:           baguette parisien
# rimozione parole duplicate:              baguette parisien
# ordinamento alfabetico:                  baguette parisien
# normalizzazione completa:                baguette parisien
#
# originale:                               "&quot;Baguette Lyonnais&quot;"
# brand rimosso:                           "&quot;baguette lyonnais&quot;"
# traduzione testo in inglese:             "&quot;baguette lyonnais&quot;"
# minuscolo:                               "&quot;baguette lyonnais&quot;"
# sigle espanse:                           "&quot;baguette lyonnais&quot;"
# rimozione aggettivi:                     `` & quot ; baguette & quot ; ''
# rimozione suffissi e prefissi:           `` & ; baguette & ; ''
# rimozione testo parentesi:               `` & ; baguette & ; ''
# rimozione testo dopo virgola:            `` & ; baguette & ; ''
# rimozione punteggiatura:                 baguette
# rimozione stopwords:                     baguette
# normalizza quantità:                     baguette
# rimozione unità di misura:               baguette
# rimozione valori numerici:               baguette
# conversione testo al singolare:          baguette
# normalizza caratteri speciali:           baguette
# rimozione parole duplicate:              baguette
# ordinamento alfabetico:                  baguette
# normalizzazione completa:                baguette
#
# originale:                               "Solène céréales poulet"
# brand rimosso:                           "solène céréales poulet"
# traduzione testo in inglese:             solene cereal chicken
# minuscolo:                               solene cereal chicken
# sigle espanse:                           solene cereal chicken
# rimozione aggettivi:                     solene cereal chicken
# rimozione suffissi e prefissi:           solene cereal chicken
# rimozione testo parentesi:               solene cereal chicken
# rimozione testo dopo virgola:            solene cereal chicken
# rimozione punteggiatura:                 solene cereal chicken
# rimozione stopwords:                     solene cereal chicken
# normalizza quantità:                     solene cereal chicken
# rimozione unità di misura:               solene cereal chicken
# rimozione valori numerici:               solene cereal chicken
# conversione testo al singolare:          solene cereal chicken
# normalizza caratteri speciali:           solene cereal chicken
# rimozione parole duplicate:              solene cereal chicken
# ordinamento alfabetico:                  cereal chicken solene
# normalizzazione completa:                cereal chicken solene
#
# originale:                               "Tarte noix de coco"
# brand rimosso:                           "tarte noix de coco"
# traduzione testo in inglese:             coconut tart
# minuscolo:                               coconut tart
# sigle espanse:                           coconut tart
# rimozione aggettivi:                     coconut tart
# rimozione suffissi e prefissi:           coconut tart
# rimozione testo parentesi:               coconut tart
# rimozione testo dopo virgola:            coconut tart
# rimozione punteggiatura:                 coconut tart
# rimozione stopwords:                     coconut tart
# normalizza quantità:                     coconut tart
# rimozione unità di misura:               coconut tart
# rimozione valori numerici:               coconut tart
# conversione testo al singolare:          coconut tart
# normalizza caratteri speciali:           coconut tart
# rimozione parole duplicate:              tart coconut
# ordinamento alfabetico:                  coconut tart
# normalizzazione completa:                coconut tart
#
# originale:                               "Fromage blanc pêche"
# brand rimosso:                           "fromage blanc pêche"
# traduzione testo in inglese:             white cheese peach
# minuscolo:                               white cheese peach
# sigle espanse:                           white cheese peach
# rimozione aggettivi:                     white cheese peach
# rimozione suffissi e prefissi:           white cheese peach
# rimozione testo parentesi:               white cheese peach
# rimozione testo dopo virgola:            white cheese peach
# rimozione punteggiatura:                 white cheese peach
# rimozione stopwords:                     white cheese peach
# normalizza quantità:                     white cheese peach
# rimozione unità di misura:               white cheese peach
# rimozione valori numerici:               white cheese peach
# conversione testo al singolare:          white cheese peach
# normalizza caratteri speciali:           white cheese peach
# rimozione parole duplicate:              cheese peach white
# ordinamento alfabetico:                  cheese peach white
# normalizzazione completa:                cheese peach white
#
# originale:                               "Crème dessert chocolat"
# brand rimosso:                           "crème dessert chocolat"
# traduzione testo in inglese:             chocolate cream dessert
# minuscolo:                               chocolate cream dessert
# sigle espanse:                           chocolate cream dessert
# rimozione aggettivi:                     chocolate cream dessert
# rimozione suffissi e prefissi:           chocolate cream dessert
# rimozione testo parentesi:               chocolate cream dessert
# rimozione testo dopo virgola:            chocolate cream dessert
# rimozione punteggiatura:                 chocolate cream dessert
# rimozione stopwords:                     chocolate cream dessert
# normalizza quantità:                     chocolate cream dessert
# rimozione unità di misura:               chocolate cream dessert
# rimozione valori numerici:               chocolate cream dessert
# conversione testo al singolare:          chocolate cream dessert
# normalizza caratteri speciali:           chocolate cream dessert
# rimozione parole duplicate:              cream dessert chocolate
# ordinamento alfabetico:                  chocolate cream dessert
# normalizzazione completa:                chocolate cream dessert
#
# originale:                               "Compote de poire"
# brand rimosso:                           "compote de poire"
# traduzione testo in inglese:             pear compote
# minuscolo:                               pear compote
# sigle espanse:                           pear compote
# rimozione aggettivi:                     pear compote
# rimozione suffissi e prefissi:           pear compote
# rimozione testo parentesi:               pear compote
# rimozione testo dopo virgola:            pear compote
# rimozione punteggiatura:                 pear compote
# rimozione stopwords:                     pear compote
# normalizza quantità:                     pear compote
# rimozione unità di misura:               pear compote
# rimozione valori numerici:               pear compote
# conversione testo al singolare:          pear compote
# normalizza caratteri speciali:           pear compote
# rimozione parole duplicate:              compote pear
# ordinamento alfabetico:                  compote pear
# normalizzazione completa:                compote pear
#
# originale:                               "Paëlla de poulet"
# brand rimosso:                           "paëlla de poulet"
# traduzione testo in inglese:             chicken paella
# minuscolo:                               chicken paella
# sigle espanse:                           chicken paella
# rimozione aggettivi:                     chicken paella
# rimozione suffissi e prefissi:           chicken paella
# rimozione testo parentesi:               chicken paella
# rimozione testo dopo virgola:            chicken paella
# rimozione punteggiatura:                 chicken paella
# rimozione stopwords:                     chicken paella
# normalizza quantità:                     chicken paella
# rimozione unità di misura:               chicken paella
# rimozione valori numerici:               chicken paella
# conversione testo al singolare:          chicken paella
# normalizza caratteri speciali:           chicken paella
# rimozione parole duplicate:              chicken paella
# ordinamento alfabetico:                  chicken paella
# normalizzazione completa:                chicken paella
#
# originale:                               "Aiguillettes de poulet"
# brand rimosso:                           "aiguillettes de poulet"
# traduzione testo in inglese:             chicken tenderloins
# minuscolo:                               chicken tenderloins
# sigle espanse:                           chicken tenderloins
# rimozione aggettivi:                     chicken tenderloins
# rimozione suffissi e prefissi:           chicken tenderloins
# rimozione testo parentesi:               chicken tenderloins
# rimozione testo dopo virgola:            chicken tenderloins
# rimozione punteggiatura:                 chicken tenderloins
# rimozione stopwords:                     chicken tenderloins
# normalizza quantità:                     chicken tenderloins
# rimozione unità di misura:               chicken tenderloins
# rimozione valori numerici:               chicken tenderloins
# conversione testo al singolare:          chicken tenderloin
# normalizza caratteri speciali:           chicken tenderloin
# rimozione parole duplicate:              tenderloin chicken
# ordinamento alfabetico:                  chicken tenderloin
# normalizzazione completa:                chicken tenderloin
#
# originale:                               "Salade shaker chef"
# brand rimosso:                           "salade shaker chef"
# traduzione testo in inglese:             shaken saladchef
# minuscolo:                               shaken saladchef
# sigle espanse:                           shaken saladchef
# rimozione aggettivi:                     shaken saladchef
# rimozione suffissi e prefissi:           shaken saladchef
# rimozione testo parentesi:               shaken saladchef
# rimozione testo dopo virgola:            shaken saladchef
# rimozione punteggiatura:                 shaken saladchef
# rimozione stopwords:                     shaken saladchef
# normalizza quantità:                     shaken saladchef
# rimozione unità di misura:               shaken saladchef
# rimozione valori numerici:               shaken saladchef
# conversione testo al singolare:          shaken saladchef
# normalizza caratteri speciali:           shaken saladchef
# rimozione parole duplicate:              saladchef shaken
# ordinamento alfabetico:                  saladchef shaken
# normalizzazione completa:                saladchef shaken
#
# originale:                               "Salade de macedoine de légumes"
# brand rimosso:                           "salade de macedoine de légumes"
# traduzione testo in inglese:             vegetable medley salad
# minuscolo:                               vegetable medley salad
# sigle espanse:                           vegetable medley salad
# rimozione aggettivi:                     vegetable medley salad
# rimozione suffissi e prefissi:           vegetable medley salad
# rimozione testo parentesi:               vegetable medley salad
# rimozione testo dopo virgola:            vegetable medley salad
# rimozione punteggiatura:                 vegetable medley salad
# rimozione stopwords:                     vegetable medley salad
# normalizza quantità:                     vegetable medley salad
# rimozione unità di misura:               vegetable medley salad
# rimozione valori numerici:               vegetable medley salad
# conversione testo al singolare:          vegetable medley salad
# normalizza caratteri speciali:           vegetable medley salad
# rimozione parole duplicate:              medley vegetable salad
# ordinamento alfabetico:                  medley salad vegetable
# normalizzazione completa:                medley salad vegetable
#
# originale:                               "Baguette Poitevin"
# brand rimosso:                           "baguette poitevin"
# traduzione testo in inglese:             "baguette poitevin"
# minuscolo:                               "baguette poitevin"
# sigle espanse:                           "baguette poitevin"
# rimozione aggettivi:                     `` baguette poitevin ''
# rimozione suffissi e prefissi:           `` baguette poitevin ''
# rimozione testo parentesi:               `` baguette poitevin ''
# rimozione testo dopo virgola:            `` baguette poitevin ''
# rimozione punteggiatura:                 baguette poitevin
# rimozione stopwords:                     baguette poitevin
# normalizza quantità:                     baguette poitevin
# rimozione unità di misura:               baguette poitevin
# rimozione valori numerici:               baguette poitevin
# conversione testo al singolare:          baguette poitevin
# normalizza caratteri speciali:           baguette poitevin
# rimozione parole duplicate:              baguette poitevin
# ordinamento alfabetico:                  baguette poitevin
# normalizzazione completa:                baguette poitevin
#
# originale:                               "Suedois thon"
# brand rimosso:                           "suedois thon"
# traduzione testo in inglese:             swedish herring
# minuscolo:                               swedish herring
# sigle espanse:                           swedish herring
# rimozione aggettivi:                     swedish herring
# rimozione suffissi e prefissi:           swedish herring
# rimozione testo parentesi:               swedish herring
# rimozione testo dopo virgola:            swedish herring
# rimozione punteggiatura:                 swedish herring
# rimozione stopwords:                     swedish herring
# normalizza quantità:                     swedish herring
# rimozione unità di misura:               swedish herring
# rimozione valori numerici:               swedish herring
# conversione testo al singolare:          swedish herring
# normalizza caratteri speciali:           swedish herring
# rimozione parole duplicate:              swedish herring
# ordinamento alfabetico:                  herring swedish
# normalizzazione completa:                herring swedish
#
# originale:                               "Ciabatta Bombay"
# brand rimosso:                           "ciabatta bombay"
# traduzione testo in inglese:             ciabatta bombay
# minuscolo:                               ciabatta bombay
# sigle espanse:                           ciabatta bombay
# rimozione aggettivi:                     ciabatta bombay
# rimozione suffissi e prefissi:           ciabatta bombay
# rimozione testo parentesi:               ciabatta bombay
# rimozione testo dopo virgola:            ciabatta bombay
# rimozione punteggiatura:                 ciabatta bombay
# rimozione stopwords:                     ciabatta bombay
# normalizza quantità:                     ciabatta bombay
# rimozione unità di misura:               ciabatta bombay
# rimozione valori numerici:               ciabatta bombay
# conversione testo al singolare:          ciabatta bombay
# normalizza caratteri speciali:           ciabatta bombay
# rimozione parole duplicate:              bombay ciabatta
# ordinamento alfabetico:                  bombay ciabatta
# normalizzazione completa:                bombay ciabatta
#
# originale:                               "Ciabatta Roma"
# brand rimosso:                           "ciabatta roma"
# traduzione testo in inglese:             romes bread
# minuscolo:                               romes bread
# sigle espanse:                           romes bread
# rimozione aggettivi:                     romes bread
# rimozione suffissi e prefissi:           romes bread
# rimozione testo parentesi:               romes bread
# rimozione testo dopo virgola:            romes bread
# rimozione punteggiatura:                 romes bread
# rimozione stopwords:                     romes bread
# normalizza quantità:                     romes bread
# rimozione unità di misura:               romes bread
# rimozione valori numerici:               romes bread
# conversione testo al singolare:          rome bread
# normalizza caratteri speciali:           rome bread
# rimozione parole duplicate:              rome bread
# ordinamento alfabetico:                  bread rome
# normalizzazione completa:                bread rome
#
# originale:                               "Salade tomate"
# brand rimosso:                           "salade tomate"
# traduzione testo in inglese:             tomato salad
# minuscolo:                               tomato salad
# sigle espanse:                           tomato salad
# rimozione aggettivi:                     tomato salad
# rimozione suffissi e prefissi:           tomato salad
# rimozione testo parentesi:               tomato salad
# rimozione testo dopo virgola:            tomato salad
# rimozione punteggiatura:                 tomato salad
# rimozione stopwords:                     tomato salad
# normalizza quantità:                     tomato salad
# rimozione unità di misura:               tomato salad
# rimozione valori numerici:               tomato salad
# conversione testo al singolare:          tomato salad
# normalizza caratteri speciali:           tomato salad
# rimozione parole duplicate:              salad tomato
# ordinamento alfabetico:                  salad tomato
# normalizzazione completa:                salad tomato
#
# originale:                               "Mousse chocolat douceur"
# brand rimosso:                           "mousse chocolat douceur"
# traduzione testo in inglese:             chocolate mousse sweetness
# minuscolo:                               chocolate mousse sweetness
# sigle espanse:                           chocolate mousse sweetness
# rimozione aggettivi:                     chocolate mousse sweetness
# rimozione suffissi e prefissi:           chocolate mousse sweetness
# rimozione testo parentesi:               chocolate mousse sweetness
# rimozione testo dopo virgola:            chocolate mousse sweetness
# rimozione punteggiatura:                 chocolate mousse sweetness
# rimozione stopwords:                     chocolate mousse sweetness
# normalizza quantità:                     chocolate mousse sweetness
# rimozione unità di misura:               chocolate mousse sweetness
# rimozione valori numerici:               chocolate mousse sweetness
# conversione testo al singolare:          chocolate mousse sweetness
# normalizza caratteri speciali:           chocolate mousse sweetness
# rimozione parole duplicate:              sweetness mousse chocolate
# ordinamento alfabetico:                  chocolate mousse sweetness
# normalizzazione completa:                chocolate mousse sweetness
#
# originale:                               "Coca des flandres"
# brand rimosso:                           "coca des flandres"
# traduzione testo in inglese:             flanders cake
# minuscolo:                               flanders cake
# sigle espanse:                           flanders cake
# rimozione aggettivi:                     flanders cake
# rimozione suffissi e prefissi:           flanders cake
# rimozione testo parentesi:               flanders cake
# rimozione testo dopo virgola:            flanders cake
# rimozione punteggiatura:                 flanders cake
# rimozione stopwords:                     flanders cake
# normalizza quantità:                     flanders cake
# rimozione unità di misura:               flanders cake
# rimozione valori numerici:               flanders cake
# conversione testo al singolare:          flanders cake
# normalizza caratteri speciali:           flanders cake
# rimozione parole duplicate:              cake flanders
# ordinamento alfabetico:                  cake flanders
# normalizzazione completa:                cake flanders
#
# originale:                               "Brochettes dinde"
# brand rimosso:                           "brochettes dinde"
# traduzione testo in inglese:             turkey skewers
# minuscolo:                               turkey skewers
# sigle espanse:                           turkey skewers
# rimozione aggettivi:                     turkey skewers
# rimozione suffissi e prefissi:           turkey skewers
# rimozione testo parentesi:               turkey skewers
# rimozione testo dopo virgola:            turkey skewers
# rimozione punteggiatura:                 turkey skewers
# rimozione stopwords:                     turkey skewers
# normalizza quantità:                     turkey skewers
# rimozione unità di misura:               turkey skewers
# rimozione valori numerici:               turkey skewers
# conversione testo al singolare:          turkey skewer
# normalizza caratteri speciali:           turkey skewer
# rimozione parole duplicate:              skewer turkey
# ordinamento alfabetico:                  skewer turkey
# normalizzazione completa:                skewer turkey
#
# originale:                               "Suedois saumon"
# brand rimosso:                           "suedois saumon"
# traduzione testo in inglese:             swedish salmon
# minuscolo:                               swedish salmon
# sigle espanse:                           swedish salmon
# rimozione aggettivi:                     swedish salmon
# rimozione suffissi e prefissi:           swedish salmon
# rimozione testo parentesi:               swedish salmon
# rimozione testo dopo virgola:            swedish salmon
# rimozione punteggiatura:                 swedish salmon
# rimozione stopwords:                     swedish salmon
# normalizza quantità:                     swedish salmon
# rimozione unità di misura:               swedish salmon
# rimozione valori numerici:               swedish salmon
# conversione testo al singolare:          swedish salmon
# normalizza caratteri speciali:           swedish salmon
# rimozione parole duplicate:              swedish salmon
# ordinamento alfabetico:                  salmon swedish
# normalizzazione completa:                salmon swedish
#
# originale:                               "Saucisse au chou fumé BBC SV (Morteau)"
# brand rimosso:                           "saucisse au chou fumé bbc sv (morteau)"
# traduzione testo in inglese:             smoked sausage with sauerkrautbbc sv morteau
# minuscolo:                               smoked sausage with sauerkrautbbc sv morteau
# sigle espanse:                           smoked sausage with sauerkrautbbc sv morteau
# rimozione aggettivi:                     smoked sausage with sv morteau
# rimozione suffissi e prefissi:           smoked sausage with sv morteau
# rimozione testo parentesi:               smoked sausage with sv morteau
# rimozione testo dopo virgola:            smoked sausage with sv morteau
# rimozione punteggiatura:                 smoked sausage with sv morteau
# rimozione stopwords:                     smoked sausage sv morteau
# normalizza quantità:                     smoked sausage sv morteau
# rimozione unità di misura:               smoked sausage sv morteau
# rimozione valori numerici:               smoked sausage sv morteau
# conversione testo al singolare:          smoked sausage sv morteau
# normalizza caratteri speciali:           smoked sausage sv morteau
# rimozione parole duplicate:              smoked morteau sv sausage
# ordinamento alfabetico:                  morteau sausage smoked sv
# normalizzazione completa:                morteau sausage smoked sv
#
# originale:                               "Crêpes au Kamok"
# brand rimosso:                           "crêpes au kamok"
# traduzione testo in inglese:             crepes with coconut milk
# minuscolo:                               crepes with coconut milk
# sigle espanse:                           crepes with coconut milk
# rimozione aggettivi:                     crepes with coconut milk
# rimozione suffissi e prefissi:           crepes with coconut milk
# rimozione testo parentesi:               crepes with coconut milk
# rimozione testo dopo virgola:            crepes with coconut milk
# rimozione punteggiatura:                 crepes with coconut milk
# rimozione stopwords:                     crepes coconut milk
# normalizza quantità:                     crepes coconut milk
# rimozione unità di misura:               crepes coconut milk
# rimozione valori numerici:               crepes coconut milk
# conversione testo al singolare:          crepe coconut milk
# normalizza caratteri speciali:           crepe coconut milk
# rimozione parole duplicate:              milk crepe coconut
# ordinamento alfabetico:                  coconut crepe milk
# normalizzazione completa:                coconut crepe milk
#
# originale:                               "Salade shaker taboulé"
# brand rimosso:                           "salade shaker taboulé"
# traduzione testo in inglese:             shaker salad tabbouleh
# minuscolo:                               shaker salad tabbouleh
# sigle espanse:                           shaker salad tabbouleh
# rimozione aggettivi:                     shaker salad tabbouleh
# rimozione suffissi e prefissi:           shaker salad tabbouleh
# rimozione testo parentesi:               shaker salad tabbouleh
# rimozione testo dopo virgola:            shaker salad tabbouleh
# rimozione punteggiatura:                 shaker salad tabbouleh
# rimozione stopwords:                     shaker salad tabbouleh
# normalizza quantità:                     shaker salad tabbouleh
# rimozione unità di misura:               shaker salad tabbouleh
# rimozione valori numerici:               shaker salad tabbouleh
# conversione testo al singolare:          shaker salad tabbouleh
# normalizza caratteri speciali:           shaker salad tabbouleh
# rimozione parole duplicate:              tabbouleh salad shaker
# ordinamento alfabetico:                  salad shaker tabbouleh
# normalizzazione completa:                salad shaker tabbouleh
#
# originale:                               "Banana Chips Sweetened (Whole)"
# brand rimosso:                           "banana chips sweetened (whole)"
# traduzione testo in inglese:             "banana chips sweetened (whole)"
# minuscolo:                               "banana chips sweetened (whole)"
# sigle espanse:                           "banana chips sweetened (whole)"
# rimozione aggettivi:                     `` chips sweetened ( whole ) ''
# rimozione suffissi e prefissi:           `` chips sweetened ( whole ) ''
# rimozione testo parentesi:               `` chips sweetened  ''
# rimozione testo dopo virgola:            `` chips sweetened  ''
# rimozione punteggiatura:                 chips sweetened
# rimozione stopwords:                     chips sweetened
# normalizza quantità:                     chips sweetened
# rimozione unità di misura:               chips sweetened
# rimozione valori numerici:               chips sweetened
# conversione testo al singolare:          chip sweetened
# normalizza caratteri speciali:           chip sweetened
# rimozione parole duplicate:              chip sweetened
# ordinamento alfabetico:                  chip sweetened
# normalizzazione completa:                chip sweetened
#
# originale:                               Peanuts
# brand rimosso:                           peanuts
# traduzione testo in inglese:             peanuts
# minuscolo:                               peanuts
# sigle espanse:                           peanuts
# rimozione aggettivi:                     peanuts
# rimozione suffissi e prefissi:           peanuts
# rimozione testo parentesi:               peanuts
# rimozione testo dopo virgola:            peanuts
# rimozione punteggiatura:                 peanuts
# rimozione stopwords:                     peanuts
# normalizza quantità:                     peanuts
# rimozione unità di misura:               peanuts
# rimozione valori numerici:               peanuts
# conversione testo al singolare:          peanut
# normalizza caratteri speciali:           peanut
# rimozione parole duplicate:              peanut
# ordinamento alfabetico:                  peanut
# normalizzazione completa:                peanut
#
# originale:                               "Sandwich classique fromage"
# brand rimosso:                           "sandwich classique fromage"
# traduzione testo in inglese:             classic cheese sandwich
# minuscolo:                               classic cheese sandwich
# sigle espanse:                           classic cheese sandwich
# rimozione aggettivi:                     classic cheese sandwich
# rimozione suffissi e prefissi:           classic cheese sandwich
# rimozione testo parentesi:               classic cheese sandwich
# rimozione testo dopo virgola:            classic cheese sandwich
# rimozione punteggiatura:                 classic cheese sandwich
# rimozione stopwords:                     classic cheese sandwich
# normalizza quantità:                     classic cheese sandwich
# rimozione unità di misura:               classic cheese sandwich
# rimozione valori numerici:               classic cheese sandwich
# conversione testo al singolare:          classic cheese sandwich
# normalizza caratteri speciali:           classic cheese sandwich
# rimozione parole duplicate:              cheese classic sandwich
# ordinamento alfabetico:                  cheese classic sandwich
# normalizzazione completa:                cheese classic sandwich
#
# originale:                               "Sandiwch Tradition Complet Jambon"
# brand rimosso:                           "sandiwch tradition complet jambon"
# traduzione testo in inglese:             sandwich traditional complete ham
# minuscolo:                               sandwich traditional complete ham
# sigle espanse:                           sandwich traditional complete ham
# rimozione aggettivi:                     sandwich traditional complete ham
# rimozione suffissi e prefissi:           sandwich traditional complete ham
# rimozione testo parentesi:               sandwich traditional complete ham
# rimozione testo dopo virgola:            sandwich traditional complete ham
# rimozione punteggiatura:                 sandwich traditional complete ham
# rimozione stopwords:                     sandwich traditional complete ham
# normalizza quantità:                     sandwich traditional complete ham
# rimozione unità di misura:               sandwich traditional complete ham
# rimozione valori numerici:               sandwich traditional complete ham
# conversione testo al singolare:          sandwich traditional complete ham
# normalizza caratteri speciali:           sandwich traditional complete ham
# rimozione parole duplicate:              ham complete sandwich traditional
# ordinamento alfabetico:                  complete ham sandwich traditional
# normalizzazione completa:                complete ham sandwich traditional
#
# originale:                               "Fromage blanc à la creme de marron"
# brand rimosso:                           "fromage blanc à la creme de marron"
# traduzione testo in inglese:             white cheese with chestnut cream
# minuscolo:                               white cheese with chestnut cream
# sigle espanse:                           white cheese with chestnut cream
# rimozione aggettivi:                     white cheese with chestnut cream
# rimozione suffissi e prefissi:           white cheese with chestnut cream
# rimozione testo parentesi:               white cheese with chestnut cream
# rimozione testo dopo virgola:            white cheese with chestnut cream
# rimozione punteggiatura:                 white cheese with chestnut cream
# rimozione stopwords:                     white cheese chestnut cream
# normalizza quantità:                     white cheese chestnut cream
# rimozione unità di misura:               white cheese chestnut cream
# rimozione valori numerici:               white cheese chestnut cream
# conversione testo al singolare:          white cheese chestnut cream
# normalizza caratteri speciali:           white cheese chestnut cream
# rimozione parole duplicate:              cheese chestnut cream white
# ordinamento alfabetico:                  cheese chestnut cream white
# normalizzazione completa:                cheese chestnut cream white
#
# originale:                               "Bio Inulin"
# brand rimosso:                           "bio inulin"
# traduzione testo in inglese:             "bio inulin"
# minuscolo:                               "bio inulin"
# sigle espanse:                           "bio inulin"
# rimozione aggettivi:                     `` bio inulin ''
# rimozione suffissi e prefissi:           `` inulin ''
# rimozione testo parentesi:               `` inulin ''
# rimozione testo dopo virgola:            `` inulin ''
# rimozione punteggiatura:                 inulin
# rimozione stopwords:                     inulin
# normalizza quantità:                     inulin
# rimozione unità di misura:               inulin
# rimozione valori numerici:               inulin
# conversione testo al singolare:          inulin
# normalizza caratteri speciali:           inulin
# rimozione parole duplicate:              inulin
# ordinamento alfabetico:                  inulin
# normalizzazione completa:                inulin
#
# originale:                               "Salade verte"
# brand rimosso:                           "salade verte"
# traduzione testo in inglese:             green salad
# minuscolo:                               green salad
# sigle espanse:                           green salad
# rimozione aggettivi:                     green salad
# rimozione suffissi e prefissi:           green salad
# rimozione testo parentesi:               green salad
# rimozione testo dopo virgola:            green salad
# rimozione punteggiatura:                 green salad
# rimozione stopwords:                     green salad
# normalizza quantità:                     green salad
# rimozione unità di misura:               green salad
# rimozione valori numerici:               green salad
# conversione testo al singolare:          green salad
# normalizza caratteri speciali:           green salad
# rimozione parole duplicate:              salad green
# ordinamento alfabetico:                  green salad
# normalizzazione completa:                green salad
#
# originale:                               "cuisse de poulet direct au four curry"
# brand rimosso:                           "cuisse de poulet direct au four curry"
# traduzione testo in inglese:             chicken thighs straight to oven curry
# minuscolo:                               chicken thighs straight to oven curry
# sigle espanse:                           chicken thighs straight to oven curry
# rimozione aggettivi:                     chicken thighs straight to curry
# rimozione suffissi e prefissi:           chicken thighs straight to curry
# rimozione testo parentesi:               chicken thighs straight to curry
# rimozione testo dopo virgola:            chicken thighs straight to curry
# rimozione punteggiatura:                 chicken thighs straight to curry
# rimozione stopwords:                     chicken thighs straight curry
# normalizza quantità:                     chicken thighs straight curry
# rimozione unità di misura:               chicken thighs straight curry
# rimozione valori numerici:               chicken thighs straight curry
# conversione testo al singolare:          chicken thigh straight curry
# normalizza caratteri speciali:           chicken thigh straight curry
# rimozione parole duplicate:              thigh straight chicken curry
# ordinamento alfabetico:                  chicken curry straight thigh
# normalizzazione completa:                chicken curry straight thigh
#
# originale:                               Bagel
# brand rimosso:                           bagel
# traduzione testo in inglese:             bagel
# minuscolo:                               bagel
# sigle espanse:                           bagel
# rimozione aggettivi:                     bagel
# rimozione suffissi e prefissi:           bagel
# rimozione testo parentesi:               bagel
# rimozione testo dopo virgola:            bagel
# rimozione punteggiatura:                 bagel
# rimozione stopwords:                     bagel
# normalizza quantità:                     bagel
# rimozione unità di misura:               bagel
# rimozione valori numerici:               bagel
# conversione testo al singolare:          bagel
# normalizza caratteri speciali:           bagel
# rimozione parole duplicate:              bagel
# ordinamento alfabetico:                  bagel
# normalizzazione completa:                bagel
#
# originale:                               "Sandwich solene céréales sicilien"
# brand rimosso:                           "sandwich solene céréales sicilien"
# traduzione testo in inglese:             "sandwich solene céréales sicilien"
# minuscolo:                               "sandwich solene céréales sicilien"
# sigle espanse:                           "sandwich solene céréales sicilien"
# rimozione aggettivi:                     `` sandwich solene céréales sicilien ''
# rimozione suffissi e prefissi:           `` sandwich solene céréales sicilien ''
# rimozione testo parentesi:               `` sandwich solene céréales sicilien ''
# rimozione testo dopo virgola:            `` sandwich solene céréales sicilien ''
# rimozione punteggiatura:                 sandwich solene céréales sicilien
# rimozione stopwords:                     sandwich solene céréales sicilien
# normalizza quantità:                     sandwich solene céréales sicilien
# rimozione unità di misura:               sandwich solene céréales sicilien
# rimozione valori numerici:               sandwich solene céréales sicilien
# conversione testo al singolare:          sandwich solene céréales sicilien
# normalizza caratteri speciali:           sandwich solene cereales sicilien
# rimozione parole duplicate:              solene cereales sicilien sandwich
# ordinamento alfabetico:                  cereales sandwich sicilien solene
# normalizzazione completa:                cereales sandwich sicilien solene
#
# originale:                               "Brioché poulet caesar"
# brand rimosso:                           "brioché poulet caesar"
# traduzione testo in inglese:             caesar chicken brioche
# minuscolo:                               caesar chicken brioche
# sigle espanse:                           caesar chicken brioche
# rimozione aggettivi:                     caesar chicken brioche
# rimozione suffissi e prefissi:           caesar chicken brioche
# rimozione testo parentesi:               caesar chicken brioche
# rimozione testo dopo virgola:            caesar chicken brioche
# rimozione punteggiatura:                 caesar chicken brioche
# rimozione stopwords:                     caesar chicken brioche
# normalizza quantità:                     caesar chicken brioche
# rimozione unità di misura:               caesar chicken brioche
# rimozione valori numerici:               caesar chicken brioche
# conversione testo al singolare:          caesar chicken brioche
# normalizza caratteri speciali:           caesar chicken brioche
# rimozione parole duplicate:              caesar chicken brioche
# ordinamento alfabetico:                  brioche caesar chicken
# normalizzazione completa:                brioche caesar chicken
#
# originale:                               "BAguette bressan"
# brand rimosso:                           "baguette bressan"
# traduzione testo in inglese:             "baguette bressan"
# minuscolo:                               "baguette bressan"
# sigle espanse:                           "baguette bressan"
# rimozione aggettivi:                     `` baguette bressan ''
# rimozione suffissi e prefissi:           `` baguette bressan ''
# rimozione testo parentesi:               `` baguette bressan ''
# rimozione testo dopo virgola:            `` baguette bressan ''
# rimozione punteggiatura:                 baguette bressan
# rimozione stopwords:                     baguette bressan
# ...
# conversione testo al singolare:          organic black bean
# normalizza caratteri speciali:           organic black bean
# rimozione parole duplicate:              organic black bean
# ordinamento alfabetico:                  bean black organic
# normalizzazione completa:                bean black organic
#
# originale:                               "Organic Hard Red Wheat Berries"
# brand rimosso:                           "organic hard red wheat berries"
# traduzione testo in inglese:             "organic hard red wheat berries"
# minuscolo:                               "organic hard red wheat berries"
# sigle espanse:                           "organic hard red wheat berries"
# rimozione aggettivi:                     `` organic hard red wheat berries ''
# rimozione suffissi e prefissi:           `` organic hard red wheat berries ''
# rimozione testo parentesi:               `` organic hard red wheat berries ''
# rimozione testo dopo virgola:            `` organic hard red wheat berries ''
# rimozione punteggiatura:                 organic hard red wheat berries
# rimozione stopwords:                     organic hard red wheat berries
# normalizza quantità:                     organic hard red wheat berries
# rimozione unità di misura:               organic hard red wheat berries
# rimozione valori numerici:               organic hard red wheat berries
# conversione testo al singolare:          organic hard red wheat berry
# normalizza caratteri speciali:           organic hard red wheat berry
# rimozione parole duplicate:              berry hard wheat red organic
# ordinamento alfabetico:                  berry hard organic red wheat
# normalizzazione completa:                berry hard organic red wheat
#
# originale:                               "Aunt Ginger's Snappy Granola"
# brand rimosso:                           "aunt ginger's snappy granola"
# traduzione testo in inglese:             "aunt ginger's snappy granola"
# minuscolo:                               "aunt ginger's snappy granola"
# sigle espanse:                           "aunt ginger's snappy granola"
# rimozione aggettivi:                     `` aunt ginger 's granola ''
# rimozione suffissi e prefissi:           `` aunt ginger 's granola ''
# rimozione testo parentesi:               `` aunt ginger 's granola ''
# rimozione testo dopo virgola:            `` aunt ginger 's granola ''
# rimozione punteggiatura:                 aunt ginger s granola
# rimozione stopwords:                     aunt ginger granola
# normalizza quantità:                     aunt ginger granola
# rimozione unità di misura:               aunt ginger granola
# rimozione valori numerici:               aunt ginger granola
# conversione testo al singolare:          aunt ginger granola
# normalizza caratteri speciali:           aunt ginger granola
# rimozione parole duplicate:              aunt granola ginger
# ordinamento alfabetico:                  aunt ginger granola
# normalizzazione completa:                aunt ginger granola
#
# originale:                               "Dark Chocolate Sea Salt & Turbinado Almonds"
# brand rimosso:                           "dark chocolate sea salt & turbinado almonds"
# traduzione testo in inglese:             "dark chocolate sea salt & turbinado almonds"
# minuscolo:                               "dark chocolate sea salt & turbinado almonds"
# sigle espanse:                           "dark chocolate sea salt & turbinado almonds"
# rimozione aggettivi:                     `` dark chocolate sea salt & turbinado almonds ''
# rimozione suffissi e prefissi:           `` dark chocolate sea salt & turbinado almonds ''
# rimozione testo parentesi:               `` dark chocolate sea salt & turbinado almonds ''
# rimozione testo dopo virgola:            `` dark chocolate sea salt & turbinado almonds ''
# rimozione punteggiatura:                 dark chocolate sea salt  turbinado almonds
# rimozione stopwords:                     dark chocolate sea salt turbinado almonds
# normalizza quantità:                     dark chocolate sea salt turbinado almonds
# rimozione unità di misura:               dark chocolate sea salt turbinado almonds
# rimozione valori numerici:               dark chocolate sea salt turbinado almonds
# conversione testo al singolare:          dark chocolate sea salt turbinado almond
# normalizza caratteri speciali:           dark chocolate sea salt turbinado almond
# rimozione parole duplicate:              dark almond chocolate salt turbinado sea
# ordinamento alfabetico:                  almond chocolate dark salt sea turbinado
# normalizzazione completa:                almond chocolate dark salt sea turbinado
#
# originale:                               "Divinely Organic Granola"
# brand rimosso:                           "divinely organic granola"
# traduzione testo in inglese:             "divinely organic granola"
# minuscolo:                               "divinely organic granola"
# sigle espanse:                           "divinely organic granola"
# rimozione aggettivi:                     `` divinely organic granola ''
# rimozione suffissi e prefissi:           `` divinely organic granola ''
# rimozione testo parentesi:               `` divinely organic granola ''
# rimozione testo dopo virgola:            `` divinely organic granola ''
# rimozione punteggiatura:                 divinely organic granola
# rimozione stopwords:                     divinely organic granola
# normalizza quantità:                     divinely organic granola
# rimozione unità di misura:               divinely organic granola
# rimozione valori numerici:               divinely organic granola
# conversione testo al singolare:          divinely organic granola
# normalizza caratteri speciali:           divinely organic granola
# rimozione parole duplicate:              divinely granola organic
# ordinamento alfabetico:                  divinely granola organic
# normalizzazione completa:                divinely granola organic
#
# originale:                               "Organic Black Chia Seeds"
# brand rimosso:                           "organic black chia seeds"
# traduzione testo in inglese:             "organic black chia seeds"
# minuscolo:                               "organic black chia seeds"
# sigle espanse:                           "organic black chia seeds"
# rimozione aggettivi:                     `` organic black chia seeds ''
# rimozione suffissi e prefissi:           `` organic black chia seeds ''
# rimozione testo parentesi:               `` organic black chia seeds ''
# rimozione testo dopo virgola:            `` organic black chia seeds ''
# rimozione punteggiatura:                 organic black chia seeds
# rimozione stopwords:                     organic black chia seeds
# normalizza quantità:                     organic black chia seeds
# rimozione unità di misura:               organic black chia seeds
# rimozione valori numerici:               organic black chia seeds
# conversione testo al singolare:          organic black chia seed
# normalizza caratteri speciali:           organic black chia seed
# rimozione parole duplicate:              seed organic black chia
# ordinamento alfabetico:                  black chia organic seed
# normalizzazione completa:                black chia organic seed
#
# originale:                               "Naturablue original"
# brand rimosso:                           "naturablue original"
# traduzione testo in inglese:             "naturablue original"
# minuscolo:                               "naturablue original"
# sigle espanse:                           "naturablue original"
# rimozione aggettivi:                     `` original ''
# rimozione suffissi e prefissi:           `` original ''
# rimozione testo parentesi:               `` original ''
# rimozione testo dopo virgola:            `` original ''
# rimozione punteggiatura:                 original
# rimozione stopwords:                     original
# normalizza quantità:                     original
# rimozione unità di misura:               original
# rimozione valori numerici:               original
# conversione testo al singolare:          original
# normalizza caratteri speciali:           original
# rimozione parole duplicate:              original
# ordinamento alfabetico:                  original
# normalizzazione completa:                original
#
# originale:                               "Les délices de la Monne"
# brand rimosso:                           "les délices de la monne"
# traduzione testo in inglese:             the delights of the monk
# minuscolo:                               the delights of the monk
# sigle espanse:                           the delights of the monk
# rimozione aggettivi:                     the delights of the monk
# rimozione suffissi e prefissi:           the delights of the monk
# rimozione testo parentesi:               the delights of the monk
# rimozione testo dopo virgola:            the delights of the monk
# rimozione punteggiatura:                 the delights of the monk
# rimozione stopwords:                     delights monk
# normalizza quantità:                     delights monk
# rimozione unità di misura:               delights monk
# rimozione valori numerici:               delights monk
# conversione testo al singolare:          delight monk
# normalizza caratteri speciali:           delight monk
# rimozione parole duplicate:              delight monk
# ordinamento alfabetico:                  delight monk
# normalizzazione completa:                delight monk
#
# originale:                               "Organic French Green Lentils"
# brand rimosso:                           "organic french green lentils"
# traduzione testo in inglese:             "organic french green lentils"
# minuscolo:                               "organic french green lentils"
# sigle espanse:                           "organic french green lentils"
# rimozione aggettivi:                     `` organic french green lentils ''
# rimozione suffissi e prefissi:           `` organic french green lentils ''
# rimozione testo parentesi:               `` organic french green lentils ''
# rimozione testo dopo virgola:            `` organic french green lentils ''
# rimozione punteggiatura:                 organic french green lentils
# rimozione stopwords:                     organic french green lentils
# normalizza quantità:                     organic french green lentils
# rimozione unità di misura:               organic french green lentils
# rimozione valori numerici:               organic french green lentils
# conversione testo al singolare:          organic french green lentil
# normalizza caratteri speciali:           organic french green lentil
# rimozione parole duplicate:              lentil organic french green
# ordinamento alfabetico:                  french green lentil organic
# normalizzazione completa:                french green lentil organic
#
# originale:                               "Organic Garbanzo Beans"
# brand rimosso:                           "organic garbanzo beans"
# traduzione testo in inglese:             "organic garbanzo beans"
# minuscolo:                               "organic garbanzo beans"
# sigle espanse:                           "organic garbanzo beans"
# rimozione aggettivi:                     `` organic garbanzo beans ''
# rimozione suffissi e prefissi:           `` organic garbanzo beans ''
# rimozione testo parentesi:               `` organic garbanzo beans ''
# rimozione testo dopo virgola:            `` organic garbanzo beans ''
# rimozione punteggiatura:                 organic garbanzo beans
# rimozione stopwords:                     organic garbanzo beans
# normalizza quantità:                     organic garbanzo beans
# rimozione unità di misura:               organic garbanzo beans
# rimozione valori numerici:               organic garbanzo beans
# conversione testo al singolare:          organic garbanzo bean
# normalizza caratteri speciali:           organic garbanzo bean
# rimozione parole duplicate:              garbanzo organic bean
# ordinamento alfabetico:                  bean garbanzo organic
# normalizzazione completa:                bean garbanzo organic
#
# originale:                               "Organic Green Split Peas"
# brand rimosso:                           "organic green split peas"
# traduzione testo in inglese:             "organic green split peas"
# minuscolo:                               "organic green split peas"
# sigle espanse:                           "organic green split peas"
# rimozione aggettivi:                     `` organic green split peas ''
# rimozione suffissi e prefissi:           `` organic green split peas ''
# rimozione testo parentesi:               `` organic green split peas ''
# rimozione testo dopo virgola:            `` organic green split peas ''
# rimozione punteggiatura:                 organic green split peas
# rimozione stopwords:                     organic green split peas
# normalizza quantità:                     organic green split peas
# rimozione unità di misura:               organic green split peas
# rimozione valori numerici:               organic green split peas
# conversione testo al singolare:          organic green split pea
# normalizza caratteri speciali:           organic green split pea
# rimozione parole duplicate:              split organic pea green
# ordinamento alfabetico:                  green organic pea split
# normalizzazione completa:                green organic pea split
#
# originale:                               "Organic Small Red Chili Beans"
# brand rimosso:                           "organic small red chili beans"
# traduzione testo in inglese:             "organic small red chili beans"
# minuscolo:                               "organic small red chili beans"
# sigle espanse:                           "organic small red chili beans"
# rimozione aggettivi:                     `` organic small red chili beans ''
# rimozione suffissi e prefissi:           `` organic small red chili beans ''
# rimozione testo parentesi:               `` organic small red chili beans ''
# rimozione testo dopo virgola:            `` organic small red chili beans ''
# rimozione punteggiatura:                 organic small red chili beans
# rimozione stopwords:                     organic small red chili beans
# normalizza quantità:                     organic small red chili beans
# rimozione unità di misura:               organic small red chili beans
# rimozione valori numerici:               organic small red chili beans
# conversione testo al singolare:          organic small red chili bean
# normalizza caratteri speciali:           organic small red chili bean
# rimozione parole duplicate:              bean red chili organic small
# ordinamento alfabetico:                  bean chili organic red small
# normalizzazione completa:                bean chili organic red small
#
# originale:                               "Organic Small White Beans"
# brand rimosso:                           "organic small white beans"
# traduzione testo in inglese:             "organic small white beans"
# minuscolo:                               "organic small white beans"
# sigle espanse:                           "organic small white beans"
# rimozione aggettivi:                     `` organic small white beans ''
# rimozione suffissi e prefissi:           `` organic small white beans ''
# rimozione testo parentesi:               `` organic small white beans ''
# rimozione testo dopo virgola:            `` organic small white beans ''
# rimozione punteggiatura:                 organic small white beans
# rimozione stopwords:                     organic small white beans
# normalizza quantità:                     organic small white beans
# rimozione unità di misura:               organic small white beans
# rimozione valori numerici:               organic small white beans
# conversione testo al singolare:          organic small white bean
# normalizza caratteri speciali:           organic small white bean
# rimozione parole duplicate:              organic small bean white
# ordinamento alfabetico:                  bean organic small white
# normalizzazione completa:                bean organic small white
#
# Normalizzazione completa
